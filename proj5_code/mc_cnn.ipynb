# %% [markdown]
# # Stereo Matching with Pytorch
#
# ## **Part 2: Learning based stereo matching**

# %% [markdown]
# Rather than of using SSD/SAD to compute a matching cost for the disparity map, in this part we will train a network to directly learn that from the data instead. You'll be implementing what has been proposed in the paper [[Zbontar & LeCun, 2015]](https://arxiv.org/abs/1409.4326) and see how it performs compare to classical cost matching approaches.
#
# **Note:**
# As a reminder, this notebook is intendend to be run on [Google Colab](https://colab.research.google.com). So first upload to Google Drive, and then change the runtime to use GPU by select "Runtime" -> "Change runtime time" -> "Hardward accelerator". Select "GPU" and click "Save".

# %% [markdown]
# ##Submission:
# Similar to part 1, this part requires a report to be submitted on gradescope along with a zip archive to be submitted on canvas containing the filled in jupyter notebook and .pth file for your best model.
#
# Fill in the relevant details in `proj5b_template.pptx` and export it as a pdf to generate the report. This has to be submitted on gradescope.
#
# ##Rubric:
# This project is worth 50 points, the points for each section is specified in `proj5b_template.pptx`.

# %% [markdown]
# ## Setup

# %% [markdown]
# For this part, we will be using Google Colab, which is a cloud based jupyter notebook environment. You can choose to run this part locally as well, especially if you have a good GPU, but the assignment is designed to run on Colab with GPU. You’ll first need to upload proj5.2_6320/mc-cnn.ipynb to Google Colab first, then you’ll be able to run them the same way you run any other notebook.
#
# In Colab, make sure you select GPU in the menu “Runtime” -> “Change runtime time” -> “Hardward accelerator”

# %% [markdown]
# ### Loading dataset and supported files
#
# Here we will download neccessary data and set up the environment. You can skip this if the data files is still in your colab environment
#
# Run the cell below only for the first run or if you want to redownload the support files

# %%
#download and extract the data -- training data

#Run the section below only for initial setup
# !gdown https://drive.google.com/u/3/uc?id=1DrTR72TafPE2KIOyrWv4doKoc2W6_JqC #Archive containing the dataset
# !unzip KITTI2015_Stereo.zip
# !rm KITTI2015_Stereo.zip

# !gdown https://drive.google.com/u/3/uc?id=138_VfDCHPqHctDOyIYcrUjbv_p7mnMb5 #Util functions
# !gdown https://drive.google.com/u/3/uc?id=1GqlD502mQsqerMTnga8aGJ62TcMGt94I #cnn_disparity_map
# !gdown https://drive.google.com/u/3/uc?id=1RAd4Dn7vcPLrIYPWMaqAh5aoHFm_2qMa #sgm

# Download and pretrainings for the appropriate window size
# !gdown https://drive.google.com/u/3/uc?id=1MjWOVFMonrgXGdLAP04rgzyMSv_CdiQ- #w5
# !gdown https://drive.google.com/u/3/uc?id=18bPMw_2ymzOvoiqUwCNZWDGfmZ5rUcvG #w9
# !gdown https://drive.google.com/u/3/uc?id=1wfWsYx91RnDNFOT-OLdSHku_DfqNzO2l #w11
# !gdown https://drive.google.com/u/3/uc?id=1FtKl3whSfTDfRQvgzNrLAhpH8dIheUS6 #w17
# Out:
# Downloading...
# From: https://drive.google.com/u/3/uc?id=1DrTR72TafPE2KIOyrWv4doKoc2W6_JqC
# To: /content/KITTI2015_Stereo.zip
# 100% 671M/671M [00:02<00:00, 259MB/s]
# Archive:  KITTI2015_Stereo.zip
#    creating: KITTI2015_Stereo/disp_noc_0/
#   inflating: KITTI2015_Stereo/disp_noc_0/000000_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000001_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000002_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000003_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000004_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000005_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000006_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000007_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000008_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000009_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000010_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000011_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000012_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000013_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000014_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000015_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000016_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000017_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000018_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000019_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000020_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000021_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000022_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000023_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000024_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000025_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000026_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000027_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000028_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000029_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000030_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000031_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000032_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000033_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000034_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000035_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000036_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000037_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000038_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000039_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000040_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000041_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000042_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000043_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000044_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000045_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000046_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000047_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000048_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000049_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000050_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000051_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000052_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000053_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000054_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000055_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000056_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000057_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000058_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000059_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000060_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000061_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000062_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000063_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000064_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000065_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000066_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000067_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000068_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000069_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000070_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000071_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000072_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000073_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000074_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000075_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000076_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000077_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000078_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000079_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000080_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000081_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000082_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000083_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000084_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000085_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000086_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000087_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000088_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000089_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000090_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000091_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000092_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000093_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000094_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000095_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000096_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000097_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000098_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000099_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000100_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000101_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000102_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000103_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000104_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000105_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000106_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000107_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000108_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000109_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000110_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000111_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000112_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000113_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000114_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000115_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000116_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000117_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000118_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000119_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000120_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000121_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000122_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000123_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000124_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000125_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000126_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000127_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000128_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000129_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000130_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000131_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000132_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000133_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000134_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000135_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000136_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000137_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000138_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000139_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000140_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000141_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000142_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000143_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000144_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000145_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000146_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000147_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000148_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000149_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000150_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000151_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000152_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000153_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000154_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000155_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000156_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000157_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000158_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000159_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000160_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000161_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000162_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000163_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000164_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000165_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000166_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000167_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000168_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000169_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000170_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000171_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000172_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000173_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000174_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000175_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000176_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000177_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000178_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000179_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000180_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000181_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000182_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000183_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000184_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000185_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000186_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000187_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000188_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000189_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000190_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000191_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000192_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000193_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000194_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000195_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000196_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000197_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000198_10.png
#   inflating: KITTI2015_Stereo/disp_noc_0/000199_10.png
#    creating: KITTI2015_Stereo/image_2/
#   inflating: KITTI2015_Stereo/image_2/000000_10.png
#   inflating: KITTI2015_Stereo/image_2/000000_11.png
#   inflating: KITTI2015_Stereo/image_2/000001_10.png
#   inflating: KITTI2015_Stereo/image_2/000001_11.png
#   inflating: KITTI2015_Stereo/image_2/000002_10.png
#   inflating: KITTI2015_Stereo/image_2/000002_11.png
#   inflating: KITTI2015_Stereo/image_2/000003_10.png
#   inflating: KITTI2015_Stereo/image_2/000003_11.png
#   inflating: KITTI2015_Stereo/image_2/000004_10.png
#   inflating: KITTI2015_Stereo/image_2/000004_11.png
#   inflating: KITTI2015_Stereo/image_2/000005_10.png
#   inflating: KITTI2015_Stereo/image_2/000005_11.png
#   inflating: KITTI2015_Stereo/image_2/000006_10.png
#   inflating: KITTI2015_Stereo/image_2/000006_11.png
#   inflating: KITTI2015_Stereo/image_2/000007_10.png
#   inflating: KITTI2015_Stereo/image_2/000007_11.png
#   inflating: KITTI2015_Stereo/image_2/000008_10.png
#   inflating: KITTI2015_Stereo/image_2/000008_11.png
#   inflating: KITTI2015_Stereo/image_2/000009_10.png
#   inflating: KITTI2015_Stereo/image_2/000009_11.png
#   inflating: KITTI2015_Stereo/image_2/000010_10.png
#   inflating: KITTI2015_Stereo/image_2/000010_11.png
#   inflating: KITTI2015_Stereo/image_2/000011_10.png
#   inflating: KITTI2015_Stereo/image_2/000011_11.png
#   inflating: KITTI2015_Stereo/image_2/000012_10.png
#   inflating: KITTI2015_Stereo/image_2/000012_11.png
#   inflating: KITTI2015_Stereo/image_2/000013_10.png
#   inflating: KITTI2015_Stereo/image_2/000013_11.png
#   inflating: KITTI2015_Stereo/image_2/000014_10.png
#   inflating: KITTI2015_Stereo/image_2/000014_11.png
#   inflating: KITTI2015_Stereo/image_2/000015_10.png
#   inflating: KITTI2015_Stereo/image_2/000015_11.png
#   inflating: KITTI2015_Stereo/image_2/000016_10.png
#   inflating: KITTI2015_Stereo/image_2/000016_11.png
#   inflating: KITTI2015_Stereo/image_2/000017_10.png
#   inflating: KITTI2015_Stereo/image_2/000017_11.png
#   inflating: KITTI2015_Stereo/image_2/000018_10.png
#   inflating: KITTI2015_Stereo/image_2/000018_11.png
#   inflating: KITTI2015_Stereo/image_2/000019_10.png
#   inflating: KITTI2015_Stereo/image_2/000019_11.png
#   inflating: KITTI2015_Stereo/image_2/000020_10.png
#   inflating: KITTI2015_Stereo/image_2/000020_11.png
#   inflating: KITTI2015_Stereo/image_2/000021_10.png
#   inflating: KITTI2015_Stereo/image_2/000021_11.png
#   inflating: KITTI2015_Stereo/image_2/000022_10.png
#   inflating: KITTI2015_Stereo/image_2/000022_11.png
#   inflating: KITTI2015_Stereo/image_2/000023_10.png
#   inflating: KITTI2015_Stereo/image_2/000023_11.png
#   inflating: KITTI2015_Stereo/image_2/000024_10.png
#   inflating: KITTI2015_Stereo/image_2/000024_11.png
#   inflating: KITTI2015_Stereo/image_2/000025_10.png
#   inflating: KITTI2015_Stereo/image_2/000025_11.png
#   inflating: KITTI2015_Stereo/image_2/000026_10.png
#   inflating: KITTI2015_Stereo/image_2/000026_11.png
#   inflating: KITTI2015_Stereo/image_2/000027_10.png
#   inflating: KITTI2015_Stereo/image_2/000027_11.png
#   inflating: KITTI2015_Stereo/image_2/000028_10.png
#   inflating: KITTI2015_Stereo/image_2/000028_11.png
#   inflating: KITTI2015_Stereo/image_2/000029_10.png
#   inflating: KITTI2015_Stereo/image_2/000029_11.png
#   inflating: KITTI2015_Stereo/image_2/000030_10.png
#   inflating: KITTI2015_Stereo/image_2/000030_11.png
#   inflating: KITTI2015_Stereo/image_2/000031_10.png
#   inflating: KITTI2015_Stereo/image_2/000031_11.png
#   inflating: KITTI2015_Stereo/image_2/000032_10.png
#   inflating: KITTI2015_Stereo/image_2/000032_11.png
#   inflating: KITTI2015_Stereo/image_2/000033_10.png
#   inflating: KITTI2015_Stereo/image_2/000033_11.png
#   inflating: KITTI2015_Stereo/image_2/000034_10.png
#   inflating: KITTI2015_Stereo/image_2/000034_11.png
#   inflating: KITTI2015_Stereo/image_2/000035_10.png
#   inflating: KITTI2015_Stereo/image_2/000035_11.png
#   inflating: KITTI2015_Stereo/image_2/000036_10.png
#   inflating: KITTI2015_Stereo/image_2/000036_11.png
#   inflating: KITTI2015_Stereo/image_2/000037_10.png
#   inflating: KITTI2015_Stereo/image_2/000037_11.png
#   inflating: KITTI2015_Stereo/image_2/000038_10.png
#   inflating: KITTI2015_Stereo/image_2/000038_11.png
#   inflating: KITTI2015_Stereo/image_2/000039_10.png
#   inflating: KITTI2015_Stereo/image_2/000039_11.png
#   inflating: KITTI2015_Stereo/image_2/000040_10.png
#   inflating: KITTI2015_Stereo/image_2/000040_11.png
#   inflating: KITTI2015_Stereo/image_2/000041_10.png
#   inflating: KITTI2015_Stereo/image_2/000041_11.png
#   inflating: KITTI2015_Stereo/image_2/000042_10.png
#   inflating: KITTI2015_Stereo/image_2/000042_11.png
#   inflating: KITTI2015_Stereo/image_2/000043_10.png
#   inflating: KITTI2015_Stereo/image_2/000043_11.png
#   inflating: KITTI2015_Stereo/image_2/000044_10.png
#   inflating: KITTI2015_Stereo/image_2/000044_11.png
#   inflating: KITTI2015_Stereo/image_2/000045_10.png
#   inflating: KITTI2015_Stereo/image_2/000045_11.png
#   inflating: KITTI2015_Stereo/image_2/000046_10.png
#   inflating: KITTI2015_Stereo/image_2/000046_11.png
#   inflating: KITTI2015_Stereo/image_2/000047_10.png
#   inflating: KITTI2015_Stereo/image_2/000047_11.png
#   inflating: KITTI2015_Stereo/image_2/000048_10.png
#   inflating: KITTI2015_Stereo/image_2/000048_11.png
#   inflating: KITTI2015_Stereo/image_2/000049_10.png
#   inflating: KITTI2015_Stereo/image_2/000049_11.png
#   inflating: KITTI2015_Stereo/image_2/000050_10.png
#   inflating: KITTI2015_Stereo/image_2/000050_11.png
#   inflating: KITTI2015_Stereo/image_2/000051_10.png
#   inflating: KITTI2015_Stereo/image_2/000051_11.png
#   inflating: KITTI2015_Stereo/image_2/000052_10.png
#   inflating: KITTI2015_Stereo/image_2/000052_11.png
#   inflating: KITTI2015_Stereo/image_2/000053_10.png
#   inflating: KITTI2015_Stereo/image_2/000053_11.png
#   inflating: KITTI2015_Stereo/image_2/000054_10.png
#   inflating: KITTI2015_Stereo/image_2/000054_11.png
#   inflating: KITTI2015_Stereo/image_2/000055_10.png
#   inflating: KITTI2015_Stereo/image_2/000055_11.png
#   inflating: KITTI2015_Stereo/image_2/000056_10.png
#   inflating: KITTI2015_Stereo/image_2/000056_11.png
#   inflating: KITTI2015_Stereo/image_2/000057_10.png
#   inflating: KITTI2015_Stereo/image_2/000057_11.png
#   inflating: KITTI2015_Stereo/image_2/000058_10.png
#   inflating: KITTI2015_Stereo/image_2/000058_11.png
#   inflating: KITTI2015_Stereo/image_2/000059_10.png
#   inflating: KITTI2015_Stereo/image_2/000059_11.png
#   inflating: KITTI2015_Stereo/image_2/000060_10.png
#   inflating: KITTI2015_Stereo/image_2/000060_11.png
#   inflating: KITTI2015_Stereo/image_2/000061_10.png
#   inflating: KITTI2015_Stereo/image_2/000061_11.png
#   inflating: KITTI2015_Stereo/image_2/000062_10.png
#   inflating: KITTI2015_Stereo/image_2/000062_11.png
#   inflating: KITTI2015_Stereo/image_2/000063_10.png
#   inflating: KITTI2015_Stereo/image_2/000063_11.png
#   inflating: KITTI2015_Stereo/image_2/000064_10.png
#   inflating: KITTI2015_Stereo/image_2/000064_11.png
#   inflating: KITTI2015_Stereo/image_2/000065_10.png
#   inflating: KITTI2015_Stereo/image_2/000065_11.png
#   inflating: KITTI2015_Stereo/image_2/000066_10.png
#   inflating: KITTI2015_Stereo/image_2/000066_11.png
#   inflating: KITTI2015_Stereo/image_2/000067_10.png
#   inflating: KITTI2015_Stereo/image_2/000067_11.png
#   inflating: KITTI2015_Stereo/image_2/000068_10.png
#   inflating: KITTI2015_Stereo/image_2/000068_11.png
#   inflating: KITTI2015_Stereo/image_2/000069_10.png
#   inflating: KITTI2015_Stereo/image_2/000069_11.png
#   inflating: KITTI2015_Stereo/image_2/000070_10.png
#   inflating: KITTI2015_Stereo/image_2/000070_11.png
#   inflating: KITTI2015_Stereo/image_2/000071_10.png
#   inflating: KITTI2015_Stereo/image_2/000071_11.png
#   inflating: KITTI2015_Stereo/image_2/000072_10.png
#   inflating: KITTI2015_Stereo/image_2/000072_11.png
#   inflating: KITTI2015_Stereo/image_2/000073_10.png
#   inflating: KITTI2015_Stereo/image_2/000073_11.png
#   inflating: KITTI2015_Stereo/image_2/000074_10.png
#   inflating: KITTI2015_Stereo/image_2/000074_11.png
#   inflating: KITTI2015_Stereo/image_2/000075_10.png
#   inflating: KITTI2015_Stereo/image_2/000075_11.png
#   inflating: KITTI2015_Stereo/image_2/000076_10.png
#   inflating: KITTI2015_Stereo/image_2/000076_11.png
#   inflating: KITTI2015_Stereo/image_2/000077_10.png
#   inflating: KITTI2015_Stereo/image_2/000077_11.png
#   inflating: KITTI2015_Stereo/image_2/000078_10.png
#   inflating: KITTI2015_Stereo/image_2/000078_11.png
#   inflating: KITTI2015_Stereo/image_2/000079_10.png
#   inflating: KITTI2015_Stereo/image_2/000079_11.png
#   inflating: KITTI2015_Stereo/image_2/000080_10.png
#   inflating: KITTI2015_Stereo/image_2/000080_11.png
#   inflating: KITTI2015_Stereo/image_2/000081_10.png
#   inflating: KITTI2015_Stereo/image_2/000081_11.png
#   inflating: KITTI2015_Stereo/image_2/000082_10.png
#   inflating: KITTI2015_Stereo/image_2/000082_11.png
#   inflating: KITTI2015_Stereo/image_2/000083_10.png
#   inflating: KITTI2015_Stereo/image_2/000083_11.png
#   inflating: KITTI2015_Stereo/image_2/000084_10.png
#   inflating: KITTI2015_Stereo/image_2/000084_11.png
#   inflating: KITTI2015_Stereo/image_2/000085_10.png
#   inflating: KITTI2015_Stereo/image_2/000085_11.png
#   inflating: KITTI2015_Stereo/image_2/000086_10.png
#   inflating: KITTI2015_Stereo/image_2/000086_11.png
#   inflating: KITTI2015_Stereo/image_2/000087_10.png
#   inflating: KITTI2015_Stereo/image_2/000087_11.png
#   inflating: KITTI2015_Stereo/image_2/000088_10.png
#   inflating: KITTI2015_Stereo/image_2/000088_11.png
#   inflating: KITTI2015_Stereo/image_2/000089_10.png
#   inflating: KITTI2015_Stereo/image_2/000089_11.png
#   inflating: KITTI2015_Stereo/image_2/000090_10.png
#   inflating: KITTI2015_Stereo/image_2/000090_11.png
#   inflating: KITTI2015_Stereo/image_2/000091_10.png
#   inflating: KITTI2015_Stereo/image_2/000091_11.png
#   inflating: KITTI2015_Stereo/image_2/000092_10.png
#   inflating: KITTI2015_Stereo/image_2/000092_11.png
#   inflating: KITTI2015_Stereo/image_2/000093_10.png
#   inflating: KITTI2015_Stereo/image_2/000093_11.png
#   inflating: KITTI2015_Stereo/image_2/000094_10.png
#   inflating: KITTI2015_Stereo/image_2/000094_11.png
#   inflating: KITTI2015_Stereo/image_2/000095_10.png
#   inflating: KITTI2015_Stereo/image_2/000095_11.png
#   inflating: KITTI2015_Stereo/image_2/000096_10.png
#   inflating: KITTI2015_Stereo/image_2/000096_11.png
#   inflating: KITTI2015_Stereo/image_2/000097_10.png
#   inflating: KITTI2015_Stereo/image_2/000097_11.png
#   inflating: KITTI2015_Stereo/image_2/000098_10.png
#   inflating: KITTI2015_Stereo/image_2/000098_11.png
#   inflating: KITTI2015_Stereo/image_2/000099_10.png
#   inflating: KITTI2015_Stereo/image_2/000099_11.png
#   inflating: KITTI2015_Stereo/image_2/000100_10.png
#   inflating: KITTI2015_Stereo/image_2/000100_11.png
#   inflating: KITTI2015_Stereo/image_2/000101_10.png
#   inflating: KITTI2015_Stereo/image_2/000101_11.png
#   inflating: KITTI2015_Stereo/image_2/000102_10.png
#   inflating: KITTI2015_Stereo/image_2/000102_11.png
#   inflating: KITTI2015_Stereo/image_2/000103_10.png
#   inflating: KITTI2015_Stereo/image_2/000103_11.png
#   inflating: KITTI2015_Stereo/image_2/000104_10.png
#   inflating: KITTI2015_Stereo/image_2/000104_11.png
#   inflating: KITTI2015_Stereo/image_2/000105_10.png
#   inflating: KITTI2015_Stereo/image_2/000105_11.png
#   inflating: KITTI2015_Stereo/image_2/000106_10.png
#   inflating: KITTI2015_Stereo/image_2/000106_11.png
#   inflating: KITTI2015_Stereo/image_2/000107_10.png
#   inflating: KITTI2015_Stereo/image_2/000107_11.png
#   inflating: KITTI2015_Stereo/image_2/000108_10.png
#   inflating: KITTI2015_Stereo/image_2/000108_11.png
#   inflating: KITTI2015_Stereo/image_2/000109_10.png
#   inflating: KITTI2015_Stereo/image_2/000109_11.png
#   inflating: KITTI2015_Stereo/image_2/000110_10.png
#   inflating: KITTI2015_Stereo/image_2/000110_11.png
#   inflating: KITTI2015_Stereo/image_2/000111_10.png
#   inflating: KITTI2015_Stereo/image_2/000111_11.png
#   inflating: KITTI2015_Stereo/image_2/000112_10.png
#   inflating: KITTI2015_Stereo/image_2/000112_11.png
#   inflating: KITTI2015_Stereo/image_2/000113_10.png
#   inflating: KITTI2015_Stereo/image_2/000113_11.png
#   inflating: KITTI2015_Stereo/image_2/000114_10.png
#   inflating: KITTI2015_Stereo/image_2/000114_11.png
#   inflating: KITTI2015_Stereo/image_2/000115_10.png
#   inflating: KITTI2015_Stereo/image_2/000115_11.png
#   inflating: KITTI2015_Stereo/image_2/000116_10.png
#   inflating: KITTI2015_Stereo/image_2/000116_11.png
#   inflating: KITTI2015_Stereo/image_2/000117_10.png
#   inflating: KITTI2015_Stereo/image_2/000117_11.png
#   inflating: KITTI2015_Stereo/image_2/000118_10.png
#   inflating: KITTI2015_Stereo/image_2/000118_11.png
#   inflating: KITTI2015_Stereo/image_2/000119_10.png
#   inflating: KITTI2015_Stereo/image_2/000119_11.png
#   inflating: KITTI2015_Stereo/image_2/000120_10.png
#   inflating: KITTI2015_Stereo/image_2/000120_11.png
#   inflating: KITTI2015_Stereo/image_2/000121_10.png
#   inflating: KITTI2015_Stereo/image_2/000121_11.png
#   inflating: KITTI2015_Stereo/image_2/000122_10.png
#   inflating: KITTI2015_Stereo/image_2/000122_11.png
#   inflating: KITTI2015_Stereo/image_2/000123_10.png
#   inflating: KITTI2015_Stereo/image_2/000123_11.png
#   inflating: KITTI2015_Stereo/image_2/000124_10.png
#   inflating: KITTI2015_Stereo/image_2/000124_11.png
#   inflating: KITTI2015_Stereo/image_2/000125_10.png
#   inflating: KITTI2015_Stereo/image_2/000125_11.png
#   inflating: KITTI2015_Stereo/image_2/000126_10.png
#   inflating: KITTI2015_Stereo/image_2/000126_11.png
#   inflating: KITTI2015_Stereo/image_2/000127_10.png
#   inflating: KITTI2015_Stereo/image_2/000127_11.png
#   inflating: KITTI2015_Stereo/image_2/000128_10.png
#   inflating: KITTI2015_Stereo/image_2/000128_11.png
#   inflating: KITTI2015_Stereo/image_2/000129_10.png
#   inflating: KITTI2015_Stereo/image_2/000129_11.png
#   inflating: KITTI2015_Stereo/image_2/000130_10.png
#   inflating: KITTI2015_Stereo/image_2/000130_11.png
#   inflating: KITTI2015_Stereo/image_2/000131_10.png
#   inflating: KITTI2015_Stereo/image_2/000131_11.png
#   inflating: KITTI2015_Stereo/image_2/000132_10.png
#   inflating: KITTI2015_Stereo/image_2/000132_11.png
#   inflating: KITTI2015_Stereo/image_2/000133_10.png
#   inflating: KITTI2015_Stereo/image_2/000133_11.png
#   inflating: KITTI2015_Stereo/image_2/000134_10.png
#   inflating: KITTI2015_Stereo/image_2/000134_11.png
#   inflating: KITTI2015_Stereo/image_2/000135_10.png
#   inflating: KITTI2015_Stereo/image_2/000135_11.png
#   inflating: KITTI2015_Stereo/image_2/000136_10.png
#   inflating: KITTI2015_Stereo/image_2/000136_11.png
#   inflating: KITTI2015_Stereo/image_2/000137_10.png
#   inflating: KITTI2015_Stereo/image_2/000137_11.png
#   inflating: KITTI2015_Stereo/image_2/000138_10.png
#   inflating: KITTI2015_Stereo/image_2/000138_11.png
#   inflating: KITTI2015_Stereo/image_2/000139_10.png
#   inflating: KITTI2015_Stereo/image_2/000139_11.png
#   inflating: KITTI2015_Stereo/image_2/000140_10.png
#   inflating: KITTI2015_Stereo/image_2/000140_11.png
#   inflating: KITTI2015_Stereo/image_2/000141_10.png
#   inflating: KITTI2015_Stereo/image_2/000141_11.png
#   inflating: KITTI2015_Stereo/image_2/000142_10.png
#   inflating: KITTI2015_Stereo/image_2/000142_11.png
#   inflating: KITTI2015_Stereo/image_2/000143_10.png
#   inflating: KITTI2015_Stereo/image_2/000143_11.png
#   inflating: KITTI2015_Stereo/image_2/000144_10.png
#   inflating: KITTI2015_Stereo/image_2/000144_11.png
#   inflating: KITTI2015_Stereo/image_2/000145_10.png
#   inflating: KITTI2015_Stereo/image_2/000145_11.png
#   inflating: KITTI2015_Stereo/image_2/000146_10.png
#   inflating: KITTI2015_Stereo/image_2/000146_11.png
#   inflating: KITTI2015_Stereo/image_2/000147_10.png
#   inflating: KITTI2015_Stereo/image_2/000147_11.png
#   inflating: KITTI2015_Stereo/image_2/000148_10.png
#   inflating: KITTI2015_Stereo/image_2/000148_11.png
#   inflating: KITTI2015_Stereo/image_2/000149_10.png
#   inflating: KITTI2015_Stereo/image_2/000149_11.png
#   inflating: KITTI2015_Stereo/image_2/000150_10.png
#   inflating: KITTI2015_Stereo/image_2/000150_11.png
#   inflating: KITTI2015_Stereo/image_2/000151_10.png
#   inflating: KITTI2015_Stereo/image_2/000151_11.png
#   inflating: KITTI2015_Stereo/image_2/000152_10.png
#   inflating: KITTI2015_Stereo/image_2/000152_11.png
#   inflating: KITTI2015_Stereo/image_2/000153_10.png
#   inflating: KITTI2015_Stereo/image_2/000153_11.png
#   inflating: KITTI2015_Stereo/image_2/000154_10.png
#   inflating: KITTI2015_Stereo/image_2/000154_11.png
#   inflating: KITTI2015_Stereo/image_2/000155_10.png
#   inflating: KITTI2015_Stereo/image_2/000155_11.png
#   inflating: KITTI2015_Stereo/image_2/000156_10.png
#   inflating: KITTI2015_Stereo/image_2/000156_11.png
#   inflating: KITTI2015_Stereo/image_2/000157_10.png
#   inflating: KITTI2015_Stereo/image_2/000157_11.png
#   inflating: KITTI2015_Stereo/image_2/000158_10.png
#   inflating: KITTI2015_Stereo/image_2/000158_11.png
#   inflating: KITTI2015_Stereo/image_2/000159_10.png
#   inflating: KITTI2015_Stereo/image_2/000159_11.png
#   inflating: KITTI2015_Stereo/image_2/000160_10.png
#   inflating: KITTI2015_Stereo/image_2/000160_11.png
#   inflating: KITTI2015_Stereo/image_2/000161_10.png
#   inflating: KITTI2015_Stereo/image_2/000161_11.png
#   inflating: KITTI2015_Stereo/image_2/000162_10.png
#   inflating: KITTI2015_Stereo/image_2/000162_11.png
#   inflating: KITTI2015_Stereo/image_2/000163_10.png
#   inflating: KITTI2015_Stereo/image_2/000163_11.png
#   inflating: KITTI2015_Stereo/image_2/000164_10.png
#   inflating: KITTI2015_Stereo/image_2/000164_11.png
#   inflating: KITTI2015_Stereo/image_2/000165_10.png
#   inflating: KITTI2015_Stereo/image_2/000165_11.png
#   inflating: KITTI2015_Stereo/image_2/000166_10.png
#   inflating: KITTI2015_Stereo/image_2/000166_11.png
#   inflating: KITTI2015_Stereo/image_2/000167_10.png
#   inflating: KITTI2015_Stereo/image_2/000167_11.png
#   inflating: KITTI2015_Stereo/image_2/000168_10.png
#   inflating: KITTI2015_Stereo/image_2/000168_11.png
#   inflating: KITTI2015_Stereo/image_2/000169_10.png
#   inflating: KITTI2015_Stereo/image_2/000169_11.png
#   inflating: KITTI2015_Stereo/image_2/000170_10.png
#   inflating: KITTI2015_Stereo/image_2/000170_11.png
#   inflating: KITTI2015_Stereo/image_2/000171_10.png
#   inflating: KITTI2015_Stereo/image_2/000171_11.png
#   inflating: KITTI2015_Stereo/image_2/000172_10.png
#   inflating: KITTI2015_Stereo/image_2/000172_11.png
#   inflating: KITTI2015_Stereo/image_2/000173_10.png
#   inflating: KITTI2015_Stereo/image_2/000173_11.png
#   inflating: KITTI2015_Stereo/image_2/000174_10.png
#   inflating: KITTI2015_Stereo/image_2/000174_11.png
#   inflating: KITTI2015_Stereo/image_2/000175_10.png
#   inflating: KITTI2015_Stereo/image_2/000175_11.png
#   inflating: KITTI2015_Stereo/image_2/000176_10.png
#   inflating: KITTI2015_Stereo/image_2/000176_11.png
#   inflating: KITTI2015_Stereo/image_2/000177_10.png
#   inflating: KITTI2015_Stereo/image_2/000177_11.png
#   inflating: KITTI2015_Stereo/image_2/000178_10.png
#   inflating: KITTI2015_Stereo/image_2/000178_11.png
#   inflating: KITTI2015_Stereo/image_2/000179_10.png
#   inflating: KITTI2015_Stereo/image_2/000179_11.png
#   inflating: KITTI2015_Stereo/image_2/000180_10.png
#   inflating: KITTI2015_Stereo/image_2/000180_11.png
#   inflating: KITTI2015_Stereo/image_2/000181_10.png
#   inflating: KITTI2015_Stereo/image_2/000181_11.png
#   inflating: KITTI2015_Stereo/image_2/000182_10.png
#   inflating: KITTI2015_Stereo/image_2/000182_11.png
#   inflating: KITTI2015_Stereo/image_2/000183_10.png
#   inflating: KITTI2015_Stereo/image_2/000183_11.png
#   inflating: KITTI2015_Stereo/image_2/000184_10.png
#   inflating: KITTI2015_Stereo/image_2/000184_11.png
#   inflating: KITTI2015_Stereo/image_2/000185_10.png
#   inflating: KITTI2015_Stereo/image_2/000185_11.png
#   inflating: KITTI2015_Stereo/image_2/000186_10.png
#   inflating: KITTI2015_Stereo/image_2/000186_11.png
#   inflating: KITTI2015_Stereo/image_2/000187_10.png
#   inflating: KITTI2015_Stereo/image_2/000187_11.png
#   inflating: KITTI2015_Stereo/image_2/000188_10.png
#   inflating: KITTI2015_Stereo/image_2/000188_11.png
#   inflating: KITTI2015_Stereo/image_2/000189_10.png
#   inflating: KITTI2015_Stereo/image_2/000189_11.png
#   inflating: KITTI2015_Stereo/image_2/000190_10.png
#   inflating: KITTI2015_Stereo/image_2/000190_11.png
#   inflating: KITTI2015_Stereo/image_2/000191_10.png
#   inflating: KITTI2015_Stereo/image_2/000191_11.png
#   inflating: KITTI2015_Stereo/image_2/000192_10.png
#   inflating: KITTI2015_Stereo/image_2/000192_11.png
#   inflating: KITTI2015_Stereo/image_2/000193_10.png
#   inflating: KITTI2015_Stereo/image_2/000193_11.png
#   inflating: KITTI2015_Stereo/image_2/000194_10.png
#   inflating: KITTI2015_Stereo/image_2/000194_11.png
#   inflating: KITTI2015_Stereo/image_2/000195_10.png
#   inflating: KITTI2015_Stereo/image_2/000195_11.png
#   inflating: KITTI2015_Stereo/image_2/000196_10.png
#   inflating: KITTI2015_Stereo/image_2/000196_11.png
#   inflating: KITTI2015_Stereo/image_2/000197_10.png
#   inflating: KITTI2015_Stereo/image_2/000197_11.png
#   inflating: KITTI2015_Stereo/image_2/000198_10.png
#   inflating: KITTI2015_Stereo/image_2/000198_11.png
#   inflating: KITTI2015_Stereo/image_2/000199_10.png
#   inflating: KITTI2015_Stereo/image_2/000199_11.png
#    creating: KITTI2015_Stereo/image_3/
#   inflating: KITTI2015_Stereo/image_3/000000_10.png
#   inflating: KITTI2015_Stereo/image_3/000000_11.png
#   inflating: KITTI2015_Stereo/image_3/000001_10.png
#   inflating: KITTI2015_Stereo/image_3/000001_11.png
#   inflating: KITTI2015_Stereo/image_3/000002_10.png
#   inflating: KITTI2015_Stereo/image_3/000002_11.png
#   inflating: KITTI2015_Stereo/image_3/000003_10.png
#   inflating: KITTI2015_Stereo/image_3/000003_11.png
#   inflating: KITTI2015_Stereo/image_3/000004_10.png
#   inflating: KITTI2015_Stereo/image_3/000004_11.png
#   inflating: KITTI2015_Stereo/image_3/000005_10.png
#   inflating: KITTI2015_Stereo/image_3/000005_11.png
#   inflating: KITTI2015_Stereo/image_3/000006_10.png
#   inflating: KITTI2015_Stereo/image_3/000006_11.png
#   inflating: KITTI2015_Stereo/image_3/000007_10.png
#   inflating: KITTI2015_Stereo/image_3/000007_11.png
#   inflating: KITTI2015_Stereo/image_3/000008_10.png
#   inflating: KITTI2015_Stereo/image_3/000008_11.png
#   inflating: KITTI2015_Stereo/image_3/000009_10.png
#   inflating: KITTI2015_Stereo/image_3/000009_11.png
#   inflating: KITTI2015_Stereo/image_3/000010_10.png
#   inflating: KITTI2015_Stereo/image_3/000010_11.png
#   inflating: KITTI2015_Stereo/image_3/000011_10.png
#   inflating: KITTI2015_Stereo/image_3/000011_11.png
#   inflating: KITTI2015_Stereo/image_3/000012_10.png
#   inflating: KITTI2015_Stereo/image_3/000012_11.png
#   inflating: KITTI2015_Stereo/image_3/000013_10.png
#   inflating: KITTI2015_Stereo/image_3/000013_11.png
#   inflating: KITTI2015_Stereo/image_3/000014_10.png
#   inflating: KITTI2015_Stereo/image_3/000014_11.png
#   inflating: KITTI2015_Stereo/image_3/000015_10.png
#   inflating: KITTI2015_Stereo/image_3/000015_11.png
#   inflating: KITTI2015_Stereo/image_3/000016_10.png
#   inflating: KITTI2015_Stereo/image_3/000016_11.png
#   inflating: KITTI2015_Stereo/image_3/000017_10.png
#   inflating: KITTI2015_Stereo/image_3/000017_11.png
#   inflating: KITTI2015_Stereo/image_3/000018_10.png
#   inflating: KITTI2015_Stereo/image_3/000018_11.png
#   inflating: KITTI2015_Stereo/image_3/000019_10.png
#   inflating: KITTI2015_Stereo/image_3/000019_11.png
#   inflating: KITTI2015_Stereo/image_3/000020_10.png
#   inflating: KITTI2015_Stereo/image_3/000020_11.png
#   inflating: KITTI2015_Stereo/image_3/000021_10.png
#   inflating: KITTI2015_Stereo/image_3/000021_11.png
#   inflating: KITTI2015_Stereo/image_3/000022_10.png
#   inflating: KITTI2015_Stereo/image_3/000022_11.png
#   inflating: KITTI2015_Stereo/image_3/000023_10.png
#   inflating: KITTI2015_Stereo/image_3/000023_11.png
#   inflating: KITTI2015_Stereo/image_3/000024_10.png
#   inflating: KITTI2015_Stereo/image_3/000024_11.png
#   inflating: KITTI2015_Stereo/image_3/000025_10.png
#   inflating: KITTI2015_Stereo/image_3/000025_11.png
#   inflating: KITTI2015_Stereo/image_3/000026_10.png
#   inflating: KITTI2015_Stereo/image_3/000026_11.png
#   inflating: KITTI2015_Stereo/image_3/000027_10.png
#   inflating: KITTI2015_Stereo/image_3/000027_11.png
#   inflating: KITTI2015_Stereo/image_3/000028_10.png
#   inflating: KITTI2015_Stereo/image_3/000028_11.png
#   inflating: KITTI2015_Stereo/image_3/000029_10.png
#   inflating: KITTI2015_Stereo/image_3/000029_11.png
#   inflating: KITTI2015_Stereo/image_3/000030_10.png
#   inflating: KITTI2015_Stereo/image_3/000030_11.png
#   inflating: KITTI2015_Stereo/image_3/000031_10.png
#   inflating: KITTI2015_Stereo/image_3/000031_11.png
#   inflating: KITTI2015_Stereo/image_3/000032_10.png
#   inflating: KITTI2015_Stereo/image_3/000032_11.png
#   inflating: KITTI2015_Stereo/image_3/000033_10.png
#   inflating: KITTI2015_Stereo/image_3/000033_11.png
#   inflating: KITTI2015_Stereo/image_3/000034_10.png
#   inflating: KITTI2015_Stereo/image_3/000034_11.png
#   inflating: KITTI2015_Stereo/image_3/000035_10.png
#   inflating: KITTI2015_Stereo/image_3/000035_11.png
#   inflating: KITTI2015_Stereo/image_3/000036_10.png
#   inflating: KITTI2015_Stereo/image_3/000036_11.png
#   inflating: KITTI2015_Stereo/image_3/000037_10.png
#   inflating: KITTI2015_Stereo/image_3/000037_11.png
#   inflating: KITTI2015_Stereo/image_3/000038_10.png
#   inflating: KITTI2015_Stereo/image_3/000038_11.png
#   inflating: KITTI2015_Stereo/image_3/000039_10.png
#   inflating: KITTI2015_Stereo/image_3/000039_11.png
#   inflating: KITTI2015_Stereo/image_3/000040_10.png
#   inflating: KITTI2015_Stereo/image_3/000040_11.png
#   inflating: KITTI2015_Stereo/image_3/000041_10.png
#   inflating: KITTI2015_Stereo/image_3/000041_11.png
#   inflating: KITTI2015_Stereo/image_3/000042_10.png
#   inflating: KITTI2015_Stereo/image_3/000042_11.png
#   inflating: KITTI2015_Stereo/image_3/000043_10.png
#   inflating: KITTI2015_Stereo/image_3/000043_11.png
#   inflating: KITTI2015_Stereo/image_3/000044_10.png
#   inflating: KITTI2015_Stereo/image_3/000044_11.png
#   inflating: KITTI2015_Stereo/image_3/000045_10.png
#   inflating: KITTI2015_Stereo/image_3/000045_11.png
#   inflating: KITTI2015_Stereo/image_3/000046_10.png
#   inflating: KITTI2015_Stereo/image_3/000046_11.png
#   inflating: KITTI2015_Stereo/image_3/000047_10.png
#   inflating: KITTI2015_Stereo/image_3/000047_11.png
#   inflating: KITTI2015_Stereo/image_3/000048_10.png
#   inflating: KITTI2015_Stereo/image_3/000048_11.png
#   inflating: KITTI2015_Stereo/image_3/000049_10.png
#   inflating: KITTI2015_Stereo/image_3/000049_11.png
#   inflating: KITTI2015_Stereo/image_3/000050_10.png
#   inflating: KITTI2015_Stereo/image_3/000050_11.png
#   inflating: KITTI2015_Stereo/image_3/000051_10.png
#   inflating: KITTI2015_Stereo/image_3/000051_11.png
#   inflating: KITTI2015_Stereo/image_3/000052_10.png
#   inflating: KITTI2015_Stereo/image_3/000052_11.png
#   inflating: KITTI2015_Stereo/image_3/000053_10.png
#   inflating: KITTI2015_Stereo/image_3/000053_11.png
#   inflating: KITTI2015_Stereo/image_3/000054_10.png
#   inflating: KITTI2015_Stereo/image_3/000054_11.png
#   inflating: KITTI2015_Stereo/image_3/000055_10.png
#   inflating: KITTI2015_Stereo/image_3/000055_11.png
#   inflating: KITTI2015_Stereo/image_3/000056_10.png
#   inflating: KITTI2015_Stereo/image_3/000056_11.png
#   inflating: KITTI2015_Stereo/image_3/000057_10.png
#   inflating: KITTI2015_Stereo/image_3/000057_11.png
#   inflating: KITTI2015_Stereo/image_3/000058_10.png
#   inflating: KITTI2015_Stereo/image_3/000058_11.png
#   inflating: KITTI2015_Stereo/image_3/000059_10.png
#   inflating: KITTI2015_Stereo/image_3/000059_11.png
#   inflating: KITTI2015_Stereo/image_3/000060_10.png
#   inflating: KITTI2015_Stereo/image_3/000060_11.png
#   inflating: KITTI2015_Stereo/image_3/000061_10.png
#   inflating: KITTI2015_Stereo/image_3/000061_11.png
#   inflating: KITTI2015_Stereo/image_3/000062_10.png
#   inflating: KITTI2015_Stereo/image_3/000062_11.png
#   inflating: KITTI2015_Stereo/image_3/000063_10.png
#   inflating: KITTI2015_Stereo/image_3/000063_11.png
#   inflating: KITTI2015_Stereo/image_3/000064_10.png
#   inflating: KITTI2015_Stereo/image_3/000064_11.png
#   inflating: KITTI2015_Stereo/image_3/000065_10.png
#   inflating: KITTI2015_Stereo/image_3/000065_11.png
#   inflating: KITTI2015_Stereo/image_3/000066_10.png
#   inflating: KITTI2015_Stereo/image_3/000066_11.png
#   inflating: KITTI2015_Stereo/image_3/000067_10.png
#   inflating: KITTI2015_Stereo/image_3/000067_11.png
#   inflating: KITTI2015_Stereo/image_3/000068_10.png
#   inflating: KITTI2015_Stereo/image_3/000068_11.png
#   inflating: KITTI2015_Stereo/image_3/000069_10.png
#   inflating: KITTI2015_Stereo/image_3/000069_11.png
#   inflating: KITTI2015_Stereo/image_3/000070_10.png
#   inflating: KITTI2015_Stereo/image_3/000070_11.png
#   inflating: KITTI2015_Stereo/image_3/000071_10.png
#   inflating: KITTI2015_Stereo/image_3/000071_11.png
#   inflating: KITTI2015_Stereo/image_3/000072_10.png
#   inflating: KITTI2015_Stereo/image_3/000072_11.png
#   inflating: KITTI2015_Stereo/image_3/000073_10.png
#   inflating: KITTI2015_Stereo/image_3/000073_11.png
#   inflating: KITTI2015_Stereo/image_3/000074_10.png
#   inflating: KITTI2015_Stereo/image_3/000074_11.png
#   inflating: KITTI2015_Stereo/image_3/000075_10.png
#   inflating: KITTI2015_Stereo/image_3/000075_11.png
#   inflating: KITTI2015_Stereo/image_3/000076_10.png
#   inflating: KITTI2015_Stereo/image_3/000076_11.png
#   inflating: KITTI2015_Stereo/image_3/000077_10.png
#   inflating: KITTI2015_Stereo/image_3/000077_11.png
#   inflating: KITTI2015_Stereo/image_3/000078_10.png
#   inflating: KITTI2015_Stereo/image_3/000078_11.png
#   inflating: KITTI2015_Stereo/image_3/000079_10.png
#   inflating: KITTI2015_Stereo/image_3/000079_11.png
#   inflating: KITTI2015_Stereo/image_3/000080_10.png
#   inflating: KITTI2015_Stereo/image_3/000080_11.png
#   inflating: KITTI2015_Stereo/image_3/000081_10.png
#   inflating: KITTI2015_Stereo/image_3/000081_11.png
#   inflating: KITTI2015_Stereo/image_3/000082_10.png
#   inflating: KITTI2015_Stereo/image_3/000082_11.png
#   inflating: KITTI2015_Stereo/image_3/000083_10.png
#   inflating: KITTI2015_Stereo/image_3/000083_11.png
#   inflating: KITTI2015_Stereo/image_3/000084_10.png
#   inflating: KITTI2015_Stereo/image_3/000084_11.png
#   inflating: KITTI2015_Stereo/image_3/000085_10.png
#   inflating: KITTI2015_Stereo/image_3/000085_11.png
#   inflating: KITTI2015_Stereo/image_3/000086_10.png
#   inflating: KITTI2015_Stereo/image_3/000086_11.png
#   inflating: KITTI2015_Stereo/image_3/000087_10.png
#   inflating: KITTI2015_Stereo/image_3/000087_11.png
#   inflating: KITTI2015_Stereo/image_3/000088_10.png
#   inflating: KITTI2015_Stereo/image_3/000088_11.png
#   inflating: KITTI2015_Stereo/image_3/000089_10.png
#   inflating: KITTI2015_Stereo/image_3/000089_11.png
#   inflating: KITTI2015_Stereo/image_3/000090_10.png
#   inflating: KITTI2015_Stereo/image_3/000090_11.png
#   inflating: KITTI2015_Stereo/image_3/000091_10.png
#   inflating: KITTI2015_Stereo/image_3/000091_11.png
#   inflating: KITTI2015_Stereo/image_3/000092_10.png
#   inflating: KITTI2015_Stereo/image_3/000092_11.png
#   inflating: KITTI2015_Stereo/image_3/000093_10.png
#   inflating: KITTI2015_Stereo/image_3/000093_11.png
#   inflating: KITTI2015_Stereo/image_3/000094_10.png
#   inflating: KITTI2015_Stereo/image_3/000094_11.png
#   inflating: KITTI2015_Stereo/image_3/000095_10.png
#   inflating: KITTI2015_Stereo/image_3/000095_11.png
#   inflating: KITTI2015_Stereo/image_3/000096_10.png
#   inflating: KITTI2015_Stereo/image_3/000096_11.png
#   inflating: KITTI2015_Stereo/image_3/000097_10.png
#   inflating: KITTI2015_Stereo/image_3/000097_11.png
#   inflating: KITTI2015_Stereo/image_3/000098_10.png
#   inflating: KITTI2015_Stereo/image_3/000098_11.png
#   inflating: KITTI2015_Stereo/image_3/000099_10.png
#   inflating: KITTI2015_Stereo/image_3/000099_11.png
#   inflating: KITTI2015_Stereo/image_3/000100_10.png
#   inflating: KITTI2015_Stereo/image_3/000100_11.png
#   inflating: KITTI2015_Stereo/image_3/000101_10.png
#   inflating: KITTI2015_Stereo/image_3/000101_11.png
#   inflating: KITTI2015_Stereo/image_3/000102_10.png
#   inflating: KITTI2015_Stereo/image_3/000102_11.png
#   inflating: KITTI2015_Stereo/image_3/000103_10.png
#   inflating: KITTI2015_Stereo/image_3/000103_11.png
#   inflating: KITTI2015_Stereo/image_3/000104_10.png
#   inflating: KITTI2015_Stereo/image_3/000104_11.png
#   inflating: KITTI2015_Stereo/image_3/000105_10.png
#   inflating: KITTI2015_Stereo/image_3/000105_11.png
#   inflating: KITTI2015_Stereo/image_3/000106_10.png
#   inflating: KITTI2015_Stereo/image_3/000106_11.png
#   inflating: KITTI2015_Stereo/image_3/000107_10.png
#   inflating: KITTI2015_Stereo/image_3/000107_11.png
#   inflating: KITTI2015_Stereo/image_3/000108_10.png
#   inflating: KITTI2015_Stereo/image_3/000108_11.png
#   inflating: KITTI2015_Stereo/image_3/000109_10.png
#   inflating: KITTI2015_Stereo/image_3/000109_11.png
#   inflating: KITTI2015_Stereo/image_3/000110_10.png
#   inflating: KITTI2015_Stereo/image_3/000110_11.png
#   inflating: KITTI2015_Stereo/image_3/000111_10.png
#   inflating: KITTI2015_Stereo/image_3/000111_11.png
#   inflating: KITTI2015_Stereo/image_3/000112_10.png
#   inflating: KITTI2015_Stereo/image_3/000112_11.png
#   inflating: KITTI2015_Stereo/image_3/000113_10.png
#   inflating: KITTI2015_Stereo/image_3/000113_11.png
#   inflating: KITTI2015_Stereo/image_3/000114_10.png
#   inflating: KITTI2015_Stereo/image_3/000114_11.png
#   inflating: KITTI2015_Stereo/image_3/000115_10.png
#   inflating: KITTI2015_Stereo/image_3/000115_11.png
#   inflating: KITTI2015_Stereo/image_3/000116_10.png
#   inflating: KITTI2015_Stereo/image_3/000116_11.png
#   inflating: KITTI2015_Stereo/image_3/000117_10.png
#   inflating: KITTI2015_Stereo/image_3/000117_11.png
#   inflating: KITTI2015_Stereo/image_3/000118_10.png
#   inflating: KITTI2015_Stereo/image_3/000118_11.png
#   inflating: KITTI2015_Stereo/image_3/000119_10.png
#   inflating: KITTI2015_Stereo/image_3/000119_11.png
#   inflating: KITTI2015_Stereo/image_3/000120_10.png
#   inflating: KITTI2015_Stereo/image_3/000120_11.png
#   inflating: KITTI2015_Stereo/image_3/000121_10.png
#   inflating: KITTI2015_Stereo/image_3/000121_11.png
#   inflating: KITTI2015_Stereo/image_3/000122_10.png
#   inflating: KITTI2015_Stereo/image_3/000122_11.png
#   inflating: KITTI2015_Stereo/image_3/000123_10.png
#   inflating: KITTI2015_Stereo/image_3/000123_11.png
#   inflating: KITTI2015_Stereo/image_3/000124_10.png
#   inflating: KITTI2015_Stereo/image_3/000124_11.png
#   inflating: KITTI2015_Stereo/image_3/000125_10.png
#   inflating: KITTI2015_Stereo/image_3/000125_11.png
#   inflating: KITTI2015_Stereo/image_3/000126_10.png
#   inflating: KITTI2015_Stereo/image_3/000126_11.png
#   inflating: KITTI2015_Stereo/image_3/000127_10.png
#   inflating: KITTI2015_Stereo/image_3/000127_11.png
#   inflating: KITTI2015_Stereo/image_3/000128_10.png
#   inflating: KITTI2015_Stereo/image_3/000128_11.png
#   inflating: KITTI2015_Stereo/image_3/000129_10.png
#   inflating: KITTI2015_Stereo/image_3/000129_11.png
#   inflating: KITTI2015_Stereo/image_3/000130_10.png
#   inflating: KITTI2015_Stereo/image_3/000130_11.png
#   inflating: KITTI2015_Stereo/image_3/000131_10.png
#   inflating: KITTI2015_Stereo/image_3/000131_11.png
#   inflating: KITTI2015_Stereo/image_3/000132_10.png
#   inflating: KITTI2015_Stereo/image_3/000132_11.png
#   inflating: KITTI2015_Stereo/image_3/000133_10.png
#   inflating: KITTI2015_Stereo/image_3/000133_11.png
#   inflating: KITTI2015_Stereo/image_3/000134_10.png
#   inflating: KITTI2015_Stereo/image_3/000134_11.png
#   inflating: KITTI2015_Stereo/image_3/000135_10.png
#   inflating: KITTI2015_Stereo/image_3/000135_11.png
#   inflating: KITTI2015_Stereo/image_3/000136_10.png
#   inflating: KITTI2015_Stereo/image_3/000136_11.png
#   inflating: KITTI2015_Stereo/image_3/000137_10.png
#   inflating: KITTI2015_Stereo/image_3/000137_11.png
#   inflating: KITTI2015_Stereo/image_3/000138_10.png
#   inflating: KITTI2015_Stereo/image_3/000138_11.png
#   inflating: KITTI2015_Stereo/image_3/000139_10.png
#   inflating: KITTI2015_Stereo/image_3/000139_11.png
#   inflating: KITTI2015_Stereo/image_3/000140_10.png
#   inflating: KITTI2015_Stereo/image_3/000140_11.png
#   inflating: KITTI2015_Stereo/image_3/000141_10.png
#   inflating: KITTI2015_Stereo/image_3/000141_11.png
#   inflating: KITTI2015_Stereo/image_3/000142_10.png
#   inflating: KITTI2015_Stereo/image_3/000142_11.png
#   inflating: KITTI2015_Stereo/image_3/000143_10.png
#   inflating: KITTI2015_Stereo/image_3/000143_11.png
#   inflating: KITTI2015_Stereo/image_3/000144_10.png
#   inflating: KITTI2015_Stereo/image_3/000144_11.png
#   inflating: KITTI2015_Stereo/image_3/000145_10.png
#   inflating: KITTI2015_Stereo/image_3/000145_11.png
#   inflating: KITTI2015_Stereo/image_3/000146_10.png
#   inflating: KITTI2015_Stereo/image_3/000146_11.png
#   inflating: KITTI2015_Stereo/image_3/000147_10.png
#   inflating: KITTI2015_Stereo/image_3/000147_11.png
#   inflating: KITTI2015_Stereo/image_3/000148_10.png
#   inflating: KITTI2015_Stereo/image_3/000148_11.png
#   inflating: KITTI2015_Stereo/image_3/000149_10.png
#   inflating: KITTI2015_Stereo/image_3/000149_11.png
#   inflating: KITTI2015_Stereo/image_3/000150_10.png
#   inflating: KITTI2015_Stereo/image_3/000150_11.png
#   inflating: KITTI2015_Stereo/image_3/000151_10.png
#   inflating: KITTI2015_Stereo/image_3/000151_11.png
#   inflating: KITTI2015_Stereo/image_3/000152_10.png
#   inflating: KITTI2015_Stereo/image_3/000152_11.png
#   inflating: KITTI2015_Stereo/image_3/000153_10.png
#   inflating: KITTI2015_Stereo/image_3/000153_11.png
#   inflating: KITTI2015_Stereo/image_3/000154_10.png
#   inflating: KITTI2015_Stereo/image_3/000154_11.png
#   inflating: KITTI2015_Stereo/image_3/000155_10.png
#   inflating: KITTI2015_Stereo/image_3/000155_11.png
#   inflating: KITTI2015_Stereo/image_3/000156_10.png
#   inflating: KITTI2015_Stereo/image_3/000156_11.png
#   inflating: KITTI2015_Stereo/image_3/000157_10.png
#   inflating: KITTI2015_Stereo/image_3/000157_11.png
#   inflating: KITTI2015_Stereo/image_3/000158_10.png
#   inflating: KITTI2015_Stereo/image_3/000158_11.png
#   inflating: KITTI2015_Stereo/image_3/000159_10.png
#   inflating: KITTI2015_Stereo/image_3/000159_11.png
#   inflating: KITTI2015_Stereo/image_3/000160_10.png
#   inflating: KITTI2015_Stereo/image_3/000160_11.png
#   inflating: KITTI2015_Stereo/image_3/000161_10.png
#   inflating: KITTI2015_Stereo/image_3/000161_11.png
#   inflating: KITTI2015_Stereo/image_3/000162_10.png
#   inflating: KITTI2015_Stereo/image_3/000162_11.png
#   inflating: KITTI2015_Stereo/image_3/000163_10.png
#   inflating: KITTI2015_Stereo/image_3/000163_11.png
#   inflating: KITTI2015_Stereo/image_3/000164_10.png
#   inflating: KITTI2015_Stereo/image_3/000164_11.png
#   inflating: KITTI2015_Stereo/image_3/000165_10.png
#   inflating: KITTI2015_Stereo/image_3/000165_11.png
#   inflating: KITTI2015_Stereo/image_3/000166_10.png
#   inflating: KITTI2015_Stereo/image_3/000166_11.png
#   inflating: KITTI2015_Stereo/image_3/000167_10.png
#   inflating: KITTI2015_Stereo/image_3/000167_11.png
#   inflating: KITTI2015_Stereo/image_3/000168_10.png
#   inflating: KITTI2015_Stereo/image_3/000168_11.png
#   inflating: KITTI2015_Stereo/image_3/000169_10.png
#   inflating: KITTI2015_Stereo/image_3/000169_11.png
#   inflating: KITTI2015_Stereo/image_3/000170_10.png
#   inflating: KITTI2015_Stereo/image_3/000170_11.png
#   inflating: KITTI2015_Stereo/image_3/000171_10.png
#   inflating: KITTI2015_Stereo/image_3/000171_11.png
#   inflating: KITTI2015_Stereo/image_3/000172_10.png
#   inflating: KITTI2015_Stereo/image_3/000172_11.png
#   inflating: KITTI2015_Stereo/image_3/000173_10.png
#   inflating: KITTI2015_Stereo/image_3/000173_11.png
#   inflating: KITTI2015_Stereo/image_3/000174_10.png
#   inflating: KITTI2015_Stereo/image_3/000174_11.png
#   inflating: KITTI2015_Stereo/image_3/000175_10.png
#   inflating: KITTI2015_Stereo/image_3/000175_11.png
#   inflating: KITTI2015_Stereo/image_3/000176_10.png
#   inflating: KITTI2015_Stereo/image_3/000176_11.png
#   inflating: KITTI2015_Stereo/image_3/000177_10.png
#   inflating: KITTI2015_Stereo/image_3/000177_11.png
#   inflating: KITTI2015_Stereo/image_3/000178_10.png
#   inflating: KITTI2015_Stereo/image_3/000178_11.png
#   inflating: KITTI2015_Stereo/image_3/000179_10.png
#   inflating: KITTI2015_Stereo/image_3/000179_11.png
#   inflating: KITTI2015_Stereo/image_3/000180_10.png
#   inflating: KITTI2015_Stereo/image_3/000180_11.png
#   inflating: KITTI2015_Stereo/image_3/000181_10.png
#   inflating: KITTI2015_Stereo/image_3/000181_11.png
#   inflating: KITTI2015_Stereo/image_3/000182_10.png
#   inflating: KITTI2015_Stereo/image_3/000182_11.png
#   inflating: KITTI2015_Stereo/image_3/000183_10.png
#   inflating: KITTI2015_Stereo/image_3/000183_11.png
#   inflating: KITTI2015_Stereo/image_3/000184_10.png
#   inflating: KITTI2015_Stereo/image_3/000184_11.png
#   inflating: KITTI2015_Stereo/image_3/000185_10.png
#   inflating: KITTI2015_Stereo/image_3/000185_11.png
#   inflating: KITTI2015_Stereo/image_3/000186_10.png
#   inflating: KITTI2015_Stereo/image_3/000186_11.png
#   inflating: KITTI2015_Stereo/image_3/000187_10.png
#   inflating: KITTI2015_Stereo/image_3/000187_11.png
#   inflating: KITTI2015_Stereo/image_3/000188_10.png
#   inflating: KITTI2015_Stereo/image_3/000188_11.png
#   inflating: KITTI2015_Stereo/image_3/000189_10.png
#   inflating: KITTI2015_Stereo/image_3/000189_11.png
#   inflating: KITTI2015_Stereo/image_3/000190_10.png
#   inflating: KITTI2015_Stereo/image_3/000190_11.png
#   inflating: KITTI2015_Stereo/image_3/000191_10.png
#   inflating: KITTI2015_Stereo/image_3/000191_11.png
#   inflating: KITTI2015_Stereo/image_3/000192_10.png
#   inflating: KITTI2015_Stereo/image_3/000192_11.png
#   inflating: KITTI2015_Stereo/image_3/000193_10.png
#   inflating: KITTI2015_Stereo/image_3/000193_11.png
#   inflating: KITTI2015_Stereo/image_3/000194_10.png
#   inflating: KITTI2015_Stereo/image_3/000194_11.png
#   inflating: KITTI2015_Stereo/image_3/000195_10.png
#   inflating: KITTI2015_Stereo/image_3/000195_11.png
#   inflating: KITTI2015_Stereo/image_3/000196_10.png
#   inflating: KITTI2015_Stereo/image_3/000196_11.png
#   inflating: KITTI2015_Stereo/image_3/000197_10.png
#   inflating: KITTI2015_Stereo/image_3/000197_11.png
#   inflating: KITTI2015_Stereo/image_3/000198_10.png
#   inflating: KITTI2015_Stereo/image_3/000198_11.png
#   inflating: KITTI2015_Stereo/image_3/000199_10.png
#   inflating: KITTI2015_Stereo/image_3/000199_11.png
# Downloading...
# From: https://drive.google.com/u/3/uc?id=138_VfDCHPqHctDOyIYcrUjbv_p7mnMb5
# To: /content/custom_utils.py
# 100% 2.85k/2.85k [00:00<00:00, 4.67MB/s]
# Downloading...
# From: https://drive.google.com/u/3/uc?id=1GqlD502mQsqerMTnga8aGJ62TcMGt94I
# To: /content/cnn_disparity_map.py
# 100% 1.96k/1.96k [00:00<00:00, 4.20MB/s]
# Downloading...
# From: https://drive.google.com/u/3/uc?id=1RAd4Dn7vcPLrIYPWMaqAh5aoHFm_2qMa
# To: /content/sgm.py
# 100% 11.4k/11.4k [00:00<00:00, 20.4MB/s]
# Downloading...
# From: https://drive.google.com/u/3/uc?id=1MjWOVFMonrgXGdLAP04rgzyMSv_CdiQ-
# To: /content/mc_cnn_pretrain_w5.pth
# 100% 11.0M/11.0M [00:00<00:00, 261MB/s]
# Downloading...
# From: https://drive.google.com/u/3/uc?id=18bPMw_2ymzOvoiqUwCNZWDGfmZ5rUcvG
# To: /content/mc_cnn_pretrain_w9.pth
# 100% 30.3M/30.3M [00:00<00:00, 275MB/s]
# Downloading...
# From: https://drive.google.com/u/3/uc?id=1wfWsYx91RnDNFOT-OLdSHku_DfqNzO2l
# To: /content/mc_cnn_pretrain_w11.pth
# 100% 44.0M/44.0M [00:00<00:00, 257MB/s]
# Downloading...
# From: https://drive.google.com/u/3/uc?id=1FtKl3whSfTDfRQvgzNrLAhpH8dIheUS6
# To: /content/mc_cnn_pretrain_w17.pth
# 100% 102M/102M [00:00<00:00, 253MB/s]

# %%
#import torch and set tensor type
import torch
# %matplotlib inline
import matplotlib.pyplot as plt

use_cuda = True and torch.cuda.is_available()
if use_cuda:
  print("Running with GPU acceleration")
device = torch.device("cuda" if use_cuda else "cpu")
tensor_type = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
torch.set_default_tensor_type(tensor_type)

torch.backends.cudnn.deterministic = True
torch.manual_seed(333) #do not change this, this is to ensure your result is reproduciable
# Out:
# Running with GPU acceleration

# %% [markdown]
# ## DataLoader

# %%
#this is loading up all the data to train
from custom_utils import DataLoader
import numpy as np
import os

data_dir = 'KITTI2015_Stereo/'

nnz = DataLoader(data_dir, verbose=False) #Might take a few secs to execute. (Set verbose=True to print out files being loaded)

X, dispnoc = nnz
# Out:
# Loaded 200 data points from KITTI2015_Stereo/

# %%
#visualize the data
#pick image for testing
ind_img = 4
print('Left Image')
plt.figure(figsize = (15,5))
plt.imshow(X[ind_img][0][0][0][0].cpu().numpy(),cmap="gray")
plt.show()
print('Right Image')
plt.figure(figsize = (15,5))
plt.imshow(X[ind_img][0][0][1][0].cpu().numpy(),cmap="gray")
plt.show()
print('Ground Truth disparity')
plt.figure(figsize = (15,5))
plt.imshow(dispnoc[ind_img].cpu().numpy(), cmap='jet')
plt.show()
# Out:
# Left Image
# Right Image
# Ground Truth disparity

# %% [markdown]
# # Network Architecture

# %% [markdown]
# In this part, **you** will be implementing **MCNET** network architecture as described in the paper.
#
# ![network_arch.png](data:image/png;base64,...)

# %% [markdown]
# The inputs to the network are 2 image patches, coming from left and right images, each will pass through a series of convolution + ReLU layers. The extracted features are then concatenated and passed through another fully connected + ReLU layers. The output is a single real number between 0 and 1, indicating the similarity between the two input images [Zbontar & LeCun, 2015]
#
# In this case, since training from scratch will take a really long time to converge, you’ll be training from our pre-trained network instead. In order to load up the pre-trained network, you must first implement the architecture exactly as described here.
#
# |Hyperparameter||
# |---|---|
# |input_patch_size|11x11|
# |num_conv_layers|5|
# |num_conv_feature_maps|112|
# |conv_kernel_size|3|
# |num_fc_layers|3|
# |num_fc_units|384|
#
# For efficiency we will convolve both input images in the same batch (this means that the input to the network will be 2xbatch_size). After the convolutional layers, we will then reshape them into (batch_size, conv_out) where conv_out is the output size of the convolutional layers. This will then be passed through a series of fully connected layers and finally a Sigmoid layer to bound the output value to 0/1.
#
# Here is the example of such network with num_conv_layers = 1 and num_fc_layers = 2:
#
#     nn.Sequential(
#             nn.Conv2d(in_channel, num_feature_map, kernel_size=kernel_size, stride=1, padding=(kernel_size//2)),
#             nn.ReLU(),
#
#             Reshape((batch_size,conv_out)), #this is a custom layer provided in the notebook which will reshape the input into the specified size
#
#             nn.Linear(conv_out,num_hidden_unit),
#             nn.ReLU(),
#             nn.Linear(num_hidden_unit,1),
#             nn.Sigmoid(),
#             )

# %%
from torch.nn.modules.conv import Conv2d
from torch import nn
from custom_utils import save_model, load_model

class Reshape(nn.Module):
    def __init__(self, shape):
        super(Reshape, self).__init__()
        self.shape = shape

    def forward(self, x):
        return x.view(*self.shape)
      
      
class MCNET(torch.nn.Module):
    """

    MCNET based on paper from [Zbontar & LeCun, 2015]. This network takes as input two patches of size 11x11 and output the 
    likelihood of the two patches being a match. 

    Args:
    -   ws: window size (or blocking size) of the input patch
    -   batch_size: batch size ,
    Returns:
    -   matching cost between the 2 patches, we use 0 for positive match (represent 0 cost to match) and 1 for negative match

    """

    def __init__(self, ws = 11, batch_size=512, load_path = None, strict=True):
        super(MCNET, self).__init__()
        
        num_feature_map = 112 
        kernel_size = 3
        num_hidden_unit = 384
        self.batch_size = batch_size
        self.ws = ws
        self.strict = strict

        self.net = nn.Sequential(
            ############################################################################
            # Student code begin
            ############################################################################
            nn.Conv2d(1, num_feature_map, kernel_size=kernel_size, stride=1, padding=kernel_size//2),
            nn.ReLU(),

            nn.Conv2d(num_feature_map, num_feature_map, kernel_size=kernel_size, stride=1, padding=kernel_size//2),
            nn.ReLU(),

            nn.Conv2d(num_feature_map, num_feature_map, kernel_size=kernel_size, stride=1, padding=kernel_size//2),
            nn.ReLU(),

            nn.Conv2d(num_feature_map, num_feature_map, kernel_size=kernel_size, stride=1, padding=kernel_size//2),
            nn.ReLU(),

            nn.Conv2d(num_feature_map, num_feature_map, kernel_size=kernel_size, stride=1, padding=kernel_size//2),
            nn.ReLU(),

            Reshape((batch_size, num_feature_map * ws * ws * 2)),

            nn.Linear(num_feature_map * ws * ws * 2, num_hidden_unit),
            nn.ReLU(),
            
            nn.Linear(num_hidden_unit,num_hidden_unit),
            nn.ReLU(),
            
            nn.Linear(num_hidden_unit,1),
            nn.Sigmoid(),

            ############################################################################
            # Student code end
            ############################################################################

        ).to(device)

        self.criterion = nn.BCELoss().to(device)
        if load_path is not None:
          self.net = load_model(self.net,load_path)

    def forward(self, x):
        
        return self.net(x)

# %% [markdown]
# Load pretrained model below to ensure the implemented architecture matches the pretrained architecture

# %%
######################################################################
#Preload the provided pretrained model, you can also load your
#saved models here.

#You can also train from scratch by setting load_path to None
#######################################################################

net_tr = MCNET(ws=11,load_path = 'mc_cnn_pretrain_w11.pth')

print(net_tr)
# Out:
# MCNET(
#   (net): Sequential(
#     (0): Conv2d(1, 112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(112, 112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(112, 112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(112, 112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): Conv2d(112, 112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): Reshape()
#     (11): Linear(in_features=27104, out_features=384, bias=True)
#     (12): ReLU()
#     (13): Linear(in_features=384, out_features=384, bias=True)
#     (14): ReLU()
#     (15): Linear(in_features=384, out_features=1, bias=True)
#     (16): Sigmoid()
#   )
#   (criterion): BCELoss()
# )

# %% [markdown]
# **Deliverables:** Network architecture implementation in MCNET and copy the output of `print(net_tr)` above to the report.
#
#
# **Questions**:
# 1.   What's the purpose of ReLU and why do we add it after every conv and fc layers?

# %% [markdown]
# **Answers**
#
# 1. ReLU is Rectified Linear Unit which has x=0 for x<0 and x=x for x>=0, this results in rectifying diminishing gradient values, i.e. when the grdient values become insignificant.

# %% [markdown]
# # Data preparation

# %%
def gen_patch(image, x, y, ws = 11):
    """
    function to return a patch of size ws at a specific location of the image.
    x, y in this case is a top left corner of the patch, for example if x,y is (0,0)
    you should return a patch over (0,0) and (ws,ws)
    
    For corner case, you can pad the output with zeros such that we always have 
    (channel, ws, ws) dimension output
    
    Args:
    -   image: image of type Tensor with dimension (channel, width, height)
    -   x: x location in the image 
    -   y: y location in the image
    -   ws: window size or block size of the patch we want
    Returns:
    -   patch: a patch of size (channel, ws, ws) of type Tensor

    """
    ############################################################################
    # Student code begin
    ############################################################################

    if x < 0 or y < 0:
      x1 = 0
      y1 = 0
    else:
      x1 = (int(x) + image.shape[1])%image.shape[1] #w-1
      y1 = (int(y) + image.shape[2])%image.shape[2]

    # print(x, y, x1, y1)

    # print(image.shape)
    image1 = torch.zeros((image.shape[0], image.shape[1]+ws-1, image.shape[2]+ws-1))
    # print(image1[:, :image.shape[1], :image.shape[2]].shape)
    image1[:, :image.shape[1], :image.shape[2]] = image

    # print(image1[:, x1:x1+ws, y1:y1+ws].shape)
    return image1[:, x1:x1+ws, y1:y1+ws]

    ############################################################################
    # Student code end
    ############################################################################

# %% [markdown]
# The following code samples patches with positive matches and negative matches from the dataset using the gen_patch() function defined above.
#
# Ensure that `patch from image A` and `positive patch from image B` looks moslty similar on multiple runs. Otherwise check your implementation for gen_patch().

# %%
import math
from custom_utils import get_disparity

ind = np.random.randint(0,len(nnz))

img, dim3, dim4, d = get_disparity(nnz,ind)

d_pos = 0
d_neg = torch.Tensor(1).uniform_(5,25)

if torch.Tensor(1) < 0.5:
    d_neg = -d_neg

x0 = X[int(img)][0][0,0]
x1 = X[int(img)][0][0,1]

anchor = gen_patch(x0, dim3, dim4)
pos = gen_patch(x1, dim3, dim4 - d + d_pos)
neg = gen_patch(x1, dim3, dim4 - d + d_neg)

fig = plt.figure(figsize=(12,4))

plt.subplot(1, 3, 1)
plt.imshow(anchor[0].cpu().numpy(),cmap='gray')
plt.title('Patch from image A')

plt.subplot(1, 3, 2)
plt.imshow(pos[0].cpu().numpy(),cmap='gray')
plt.title('Positive patch from image B')

plt.subplot(1, 3, 3)
plt.imshow(neg[0].cpu().numpy(),cmap='gray')
plt.title('Negative patch from image B')

fig.suptitle('Patch examples')
plt.show()

# %% [markdown]
# **Deliverables:** Implement gen_patch() function and copy the patch example above to the report
#
# **Questions:**
# 1.   Giving a true disparity map for each stereo pair, how do we extract positive and negative patches for the training?

# %% [markdown]
# **Answers**
#
# 1. We extract positive patches by taking the patch with shifted true disparity d. For negative patch we generate a random number and add the number to the disparity caculation which will give a wrong patch.

# %% [markdown]
# # Train

# %% [markdown]
# In the following part, the goal is to train a network that learn how to classify 2 patches as positive vs negative match. Your task is to train a best network by experimenting with the learning parameters below. There is no coding required in this part, but you should familiarize yourself with how the training and tuning parameters work.

# %%
def run_net(model, nnz, batch_size, ws=11,  max_epoch=1, split='train', optimizer=None, viz_frequency=1, save_frequency=200, fname="mc_cnn_network.pth"):
    epoch = 1
    loss_history = []
    datalen = int(nnz[1].shape[0])
    num_samples = int(2e3)
    try:
        for epoch in range(max_epoch):
            for t in range(1, int(num_samples - batch_size // 2), batch_size // 2):
                x_batch_tr = torch.zeros(batch_size*2, 1, ws, ws).type(tensor_type).to(device)
                y_batch_tr = torch.zeros(batch_size).type(tensor_type).to(device)
                x_batch_tr_ = torch.zeros(x_batch_tr.size()).to(device)
                y_batch_tr_ = torch.zeros(y_batch_tr.size()).to(device)
                for i in range(1,batch_size//2 + 1):
                    d_pos = 0
                    d_neg = torch.Tensor(1).uniform_(1.5,18)

                    if torch.rand(1) < 0.5:
                        d_neg = -d_neg
			  
                    if split=='train':
                        ind = torch.randint(10, datalen, (1,))[0]
                    elif split=='test':
                        ind = torch.randint(0, 10, (1,))[0]
                    img, dim3, dim4, d = get_disparity(nnz,ind)

                    if len(X[int(img)]) == 0:
                        continue

                    x0 = X[int(img)][0][0,0]
                    x1 = X[int(img)][0][0,1]

                    #normalize image
                    x0 = x0.add(-x0.mean()).div(x0.std())
                    x1 = x1.add(-x1.mean()).div(x1.std())

                    x_batch_tr_[i * 4 - 4] = gen_patch(x0, dim3, dim4, ws=ws)
                    x_batch_tr_[i * 4 - 3] = gen_patch(x1, dim3, dim4 - d + d_pos, ws=ws)
                    x_batch_tr_[i * 4 - 2] = gen_patch(x0,  dim3, dim4, ws=ws)
                    x_batch_tr_[i * 4 - 1] = gen_patch(x1, dim3, dim4 - d + d_neg, ws=ws)

                    y_batch_tr_[i*2-2] = 0
                    y_batch_tr_[i*2-1] = 1

                x_batch_tr = (x_batch_tr_).clone()
                y_batch_tr = (y_batch_tr_).clone()

                output = model(x_batch_tr)
                loss = model.criterion(output,y_batch_tr.view(batch_size,1))
                if split == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                loss_history.append(loss.data.cpu().numpy())
                
            if ((epoch) % viz_frequency) == 0:
                print(f'Iteration: {epoch}, Loss: {loss.data}')
				
            if epoch == 1 or ((epoch) % save_frequency) == 0:
                save_model(model.net,fname)
    except KeyboardInterrupt:
        save_model(model.net,"bk_"+fname)
    return loss_history

# %% [markdown]
# You are all set to train your model. Try experimenting with the various parameters in the cell below to train different models. Evaluate your models using the evaluate_model() function provided in the subsequent cells. Try to Train a model which has a validation_loss less then 0.3
#
# Pretrained weights are provided for windows sizes 5,9,11,17. Set variable `load_pth = 'mc_cnn_pretrain_w<ws>.pth'` to load them. For other window sizes, the model has to be trained from scratch.
#
# During training the model is saved as `save_pth` every save_frequency iterations. Use this variable to save multiple models, **remember to download your saved models before closing the notebook and they get deleted on the notebook is closed**. You can access them from the files tab on the left. You can also set load_pth as you saved .pth file to continue training on your saved model.
#
# P.S.: If the training is stopped by a keyboard interrupt, the latest trained model is saved as bk_+save_pth

# %%
#train
import math
import time
st = time.time()

viz_frequency = 5
save_frequency = 50 #for saving model

############# EXPERIMENT WITH THESE ########

save_pth = 'mc_cnn_trained_w11.pth' #The filename to save your model, feel free to change the name
load_pth = 'mc_cnn_pretrain_w11.pth' #The filename to load previously trained model

#you can change this to load up pretrain network for other window size
#net_tr = MCNET(ws=11, batch_size = 512, load_path = None) #Use this model to train from scratch
net_tr = MCNET(ws=11, batch_size = 512, load_path = load_pth) 

max_epoch = 500
learning_rate = 1e-5 # Try values 2,1,0.1,0.01,1e-5

#Swap out optimizers to identify which works best for your model.
#optimizer = torch.optim.Adam(net_tr.net.parameters(), lr=learning_rate)
optimizer = torch.optim.SGD(net_tr.net.parameters(), lr=learning_rate, momentum=0.9)
############################################

batch_size = net_tr.batch_size
ws = net_tr.ws

loss_history = run_net(model=net_tr,
                       nnz=nnz, 
                       batch_size=batch_size, 
                       ws=ws, 
                       max_epoch=max_epoch, 
                       split='train', 
                       optimizer=optimizer,
                       viz_frequency=viz_frequency, 
                       save_frequency=save_frequency,
                       fname = save_pth
                      )

print('Time elasped: ', time.time() - st) 

print('Training Loss')
plt.plot(loss_history)
plt.show()
# Out:
# Iteration: 0, Loss: 0.33924248814582825
# Iteration: 5, Loss: 0.3738946318626404
# Iteration: 10, Loss: 0.38030678033828735
# Iteration: 15, Loss: 0.41867655515670776
# Iteration: 20, Loss: 0.3144490122795105
# Iteration: 25, Loss: 0.3288170099258423
# Iteration: 30, Loss: 0.34207308292388916
# Iteration: 35, Loss: 0.4024207592010498
# Iteration: 40, Loss: 0.3255440592765808
# Iteration: 45, Loss: 0.3519027829170227
# Iteration: 50, Loss: 0.35430505871772766
# Iteration: 55, Loss: 0.3339366912841797
# Iteration: 60, Loss: 0.36992019414901733
# Iteration: 65, Loss: 0.41869616508483887
# Iteration: 70, Loss: 0.3237606883049011
# Iteration: 75, Loss: 0.3446078300476074
# Iteration: 80, Loss: 0.3726726174354553
# Iteration: 85, Loss: 0.3365097939968109
# Iteration: 90, Loss: 0.3592298924922943
# Iteration: 95, Loss: 0.3966544270515442
# Iteration: 100, Loss: 0.4067186713218689
# Iteration: 105, Loss: 0.4112209677696228
# Iteration: 110, Loss: 0.35620635747909546
# Iteration: 115, Loss: 0.4070347547531128
# Iteration: 120, Loss: 0.31674283742904663
# Iteration: 125, Loss: 0.3632282614707947
# Iteration: 130, Loss: 0.3355347216129303
# Iteration: 135, Loss: 0.3557508587837219
# Iteration: 140, Loss: 0.4054619371891022
# Iteration: 145, Loss: 0.4026671051979065
# Iteration: 150, Loss: 0.33893343806266785
# Iteration: 155, Loss: 0.3515382707118988
# Iteration: 160, Loss: 0.3314441442489624
# Iteration: 165, Loss: 0.3742523193359375
# Iteration: 170, Loss: 0.3449392318725586
# Iteration: 175, Loss: 0.3156510591506958
# Iteration: 180, Loss: 0.3997294306755066
# Iteration: 185, Loss: 0.3558332622051239
# Iteration: 190, Loss: 0.32890331745147705
# Iteration: 195, Loss: 0.3608376979827881
# Iteration: 200, Loss: 0.3355598449707031
# Iteration: 205, Loss: 0.3869258165359497
# Iteration: 210, Loss: 0.3849851191043854
# Iteration: 215, Loss: 0.37488487362861633
# Iteration: 220, Loss: 0.41866791248321533
# Iteration: 225, Loss: 0.3705028295516968
# Iteration: 230, Loss: 0.3551614284515381
# Iteration: 235, Loss: 0.3445425033569336
# Iteration: 240, Loss: 0.41679757833480835
# Iteration: 245, Loss: 0.35772234201431274
# Iteration: 250, Loss: 0.3385764956474304
# Iteration: 255, Loss: 0.36215561628341675
# Iteration: 260, Loss: 0.35440999269485474
# Iteration: 265, Loss: 0.34625333547592163
# Iteration: 270, Loss: 0.41306862235069275
# Iteration: 275, Loss: 0.338392436504364
# Iteration: 280, Loss: 0.4071963429450989
# Iteration: 285, Loss: 0.36903661489486694
# Iteration: 290, Loss: 0.3419555425643921
# Iteration: 295, Loss: 0.3440133035182953
# Iteration: 300, Loss: 0.39484113454818726
# Iteration: 305, Loss: 0.3373868465423584
# Iteration: 310, Loss: 0.3602847456932068
# Iteration: 315, Loss: 0.38363710045814514
# Iteration: 320, Loss: 0.3524967432022095
# Iteration: 325, Loss: 0.3141903579235077
# Iteration: 330, Loss: 0.3083559274673462
# Iteration: 335, Loss: 0.3409346342086792
# Iteration: 340, Loss: 0.39085108041763306
# Iteration: 345, Loss: 0.3302633762359619
# Iteration: 350, Loss: 0.3760071396827698
# Iteration: 355, Loss: 0.3195825219154358
# Iteration: 360, Loss: 0.3741593360900879
# Iteration: 365, Loss: 0.3321378231048584
# Iteration: 370, Loss: 0.35001152753829956
# Iteration: 375, Loss: 0.35710152983665466
# Iteration: 380, Loss: 0.36946287751197815
# Iteration: 385, Loss: 0.3423965275287628
# Iteration: 390, Loss: 0.32919275760650635
# Iteration: 395, Loss: 0.39363789558410645
# Iteration: 400, Loss: 0.35151615738868713
# Iteration: 405, Loss: 0.3430994153022766
# Iteration: 410, Loss: 0.35407131910324097
# Iteration: 415, Loss: 0.382199227809906
# Iteration: 420, Loss: 0.37067586183547974
# Iteration: 425, Loss: 0.39317601919174194
# Iteration: 430, Loss: 0.3678622245788574
# Iteration: 435, Loss: 0.35907793045043945
# Iteration: 440, Loss: 0.38458847999572754
# Iteration: 445, Loss: 0.3608958423137665
# Iteration: 450, Loss: 0.3118225932121277
# Iteration: 455, Loss: 0.3390337824821472
# Iteration: 460, Loss: 0.37202006578445435
# Iteration: 465, Loss: 0.3605550527572632
# Iteration: 470, Loss: 0.3603098392486572
# Iteration: 475, Loss: 0.3885931968688965
# Iteration: 480, Loss: 0.34801870584487915
# Iteration: 485, Loss: 0.33836981654167175
# Iteration: 490, Loss: 0.38544631004333496
# Iteration: 495, Loss: 0.3613816797733307
# Time elasped:  1427.2930116653442
# Training Loss

# %%
def evaluate_network(network):

  #compute loss on the held out validation set 
  num_test_epochs = 50
  
  batch_size = network.batch_size
  ws = network.ws

  loss_history = run_net(model=network,
                         nnz=nnz, 
                         batch_size=batch_size, 
                         ws=ws, 
                         max_epoch=num_test_epochs, 
                         split='test', 
                         viz_frequency=num_test_epochs+1, 
                         save_frequency=save_frequency)
  
   #validation_loss))
  return np.mean(np.array(loss_history))

# %%
load_pth = 'mc_cnn_pretrain_w11.pth'
net_te = MCNET(ws=11, load_path = load_pth) #The model to be validated
val_loss = evaluate_network(net_te)

print('Final average validation loss:', val_loss)
# Out:
# Iteration: 0, Loss: 0.41760724782943726
# Final average validation loss: 0.39163604

# %% [markdown]
# **Deliverables:** train the network to achieve the lowest error as possible. Copy the training loss plot and the final validation loss to the report.
#
# **Questions:**
#
#
# 1.   How does changing learning rate (try using large (> 1) vs small value (< 1e-5)) effect the training? Why do you think that's the case?
# 2.   What's the difference between Adam and SGD? What do you notice when switching between them?
# 3.   Is your validation loss lower or higher than your training loss? What is the reason for that? How would we get a better validation loss?

# %% [markdown]
# **Answers:**
#
# 1. Learning rate >1 keeps overshooting the error from he local minima. On the other hand learning rate < 1e-5 reduces the learning and takes very long to train the network requiring more and more epochs.
#
# 2. Adam converges early but since we are using pretrained network here, SGD gives an overall more optimal solution hencce SGD gave a better result.
#
# 3. Validation Loss is higher than the training loss but not by much. Training loss is ~0.36, while validation loss is ~0.39

# %% [markdown]
# ## Vary window size

# %% [markdown]
# In the previous section, we use window size of 11 as suggested in the paper, meaning that the input to the network will be patches of size 11x11. This corresponds to the block size that will be used when perform stereo matching later on.
#
# In this part we would like you to experiment with other window size, namely 5x5, 9x9, and 15x15 and compare the performance. You can set this in the previous cell for training, Feel free to make copies of previous cells to achieve this.

# %%
save_pth = 'mc_cnn_trained_w5.pth' #The filename to save your model, feel free to change the name
load_pth = 'mc_cnn_pretrain_w5.pth' #The filename to load previously trained model

net_tr = MCNET(ws=5, batch_size = 512, load_path = load_pth) 

max_epoch = 200
learning_rate = 0.01

optimizer = torch.optim.SGD(net_tr.net.parameters(), lr=learning_rate, momentum=0.9)
############################################

batch_size = net_tr.batch_size
ws = net_tr.ws

loss_history = run_net(model=net_tr,
                       nnz=nnz, 
                       batch_size=batch_size, 
                       ws=ws, 
                       max_epoch=max_epoch, 
                       split='train', 
                       optimizer=optimizer,
                       viz_frequency=viz_frequency, 
                       save_frequency=save_frequency,
                       fname = save_pth
                      )

print('Time elasped: ', time.time() - st) 

print('Training Loss')
plt.plot(loss_history)
plt.show()
# Out:
# Iteration: 0, Loss: 0.5531185865402222
# Iteration: 5, Loss: 0.5622406005859375
# Iteration: 10, Loss: 0.5241899490356445
# Iteration: 15, Loss: 0.5206315517425537
# Iteration: 20, Loss: 0.5389077663421631
# Iteration: 25, Loss: 0.5439673662185669
# Iteration: 30, Loss: 0.5390905141830444
# Iteration: 35, Loss: 0.510334849357605
# Iteration: 40, Loss: 0.5068914890289307
# Iteration: 45, Loss: 0.506202757358551
# Iteration: 50, Loss: 0.5029604434967041
# Iteration: 55, Loss: 0.5435054302215576
# Iteration: 60, Loss: 0.5158239006996155
# Iteration: 65, Loss: 0.5226513147354126
# Iteration: 70, Loss: 0.541171669960022
# Iteration: 75, Loss: 0.5283981561660767
# Iteration: 80, Loss: 0.531174898147583
# Iteration: 85, Loss: 0.519336462020874
# Iteration: 90, Loss: 0.49963077902793884
# Iteration: 95, Loss: 0.4910353422164917
# Iteration: 100, Loss: 0.4997856020927429
# Iteration: 105, Loss: 0.4925236105918884
# Iteration: 110, Loss: 0.5161888003349304
# Iteration: 115, Loss: 0.48109862208366394
# Iteration: 120, Loss: 0.526762068271637
# Iteration: 125, Loss: 0.5390442609786987
# Iteration: 130, Loss: 0.4832526445388794
# Iteration: 135, Loss: 0.5042626857757568
# Iteration: 140, Loss: 0.4637967646121979
# Iteration: 145, Loss: 0.45105189085006714
# Iteration: 150, Loss: 0.4671125113964081
# Iteration: 155, Loss: 0.5254665613174438
# Iteration: 160, Loss: 0.5126291513442993
# Iteration: 165, Loss: 0.45986703038215637
# Iteration: 170, Loss: 0.5003598928451538
# Iteration: 175, Loss: 0.4875032901763916
# Iteration: 180, Loss: 0.49729061126708984
# Iteration: 185, Loss: 0.4756432771682739
# Iteration: 190, Loss: 0.45587021112442017
# Iteration: 195, Loss: 0.48231199383735657
# Time elasped:  4316.854949712753
# Training Loss

# %%
save_pth = 'mc_cnn_trained_w9.pth' #The filename to save your model, feel free to change the name
load_pth = 'mc_cnn_pretrain_w9.pth' #The filename to load previously trained model

net_tr = MCNET(ws=9, batch_size = 512, load_path = load_pth) 

max_epoch = 200
learning_rate = 0.01

optimizer = torch.optim.SGD(net_tr.net.parameters(), lr=learning_rate, momentum=0.9)
############################################

batch_size = net_tr.batch_size
ws = net_tr.ws

loss_history = run_net(model=net_tr,
                       nnz=nnz, 
                       batch_size=batch_size, 
                       ws=ws, 
                       max_epoch=max_epoch, 
                       split='train', 
                       optimizer=optimizer,
                       viz_frequency=viz_frequency, 
                       save_frequency=save_frequency,
                       fname = save_pth
                      )

print('Time elasped: ', time.time() - st) 

print('Training Loss')
plt.plot(loss_history)
plt.show()
# Out:
# Iteration: 0, Loss: 0.44312554597854614
# Iteration: 5, Loss: 0.38472193479537964
# Iteration: 10, Loss: 0.40757036209106445
# Iteration: 15, Loss: 0.3662616014480591
# Iteration: 20, Loss: 0.34335434436798096
# Iteration: 25, Loss: 0.40860694646835327
# Iteration: 30, Loss: 0.36859312653541565
# Iteration: 35, Loss: 0.3716627061367035
# Iteration: 40, Loss: 0.38094156980514526
# Iteration: 45, Loss: 0.408253014087677
# Iteration: 50, Loss: 0.37918218970298767
# Iteration: 55, Loss: 0.36620521545410156
# Iteration: 60, Loss: 0.3643020987510681
# Iteration: 65, Loss: 0.3814394474029541
# Iteration: 70, Loss: 0.3338014483451843
# Iteration: 75, Loss: 0.3837132155895233
# Iteration: 80, Loss: 0.39474794268608093
# Iteration: 85, Loss: 0.4054145812988281
# Iteration: 90, Loss: 0.3599243760108948
# Iteration: 95, Loss: 0.40579500794410706
# Iteration: 100, Loss: 0.3926926553249359
# Iteration: 105, Loss: 0.36263638734817505
# Iteration: 110, Loss: 0.3612239360809326
# Iteration: 115, Loss: 0.38019847869873047
# Iteration: 120, Loss: 0.3306363523006439
# Iteration: 125, Loss: 0.37314513325691223
# Iteration: 130, Loss: 0.3895970582962036
# Iteration: 135, Loss: 0.35569483041763306
# Iteration: 140, Loss: 0.38704973459243774
# Iteration: 145, Loss: 0.3033437430858612
# Iteration: 150, Loss: 0.4079451560974121
# Iteration: 155, Loss: 0.38203129172325134
# Iteration: 160, Loss: 0.3817495107650757
# Iteration: 165, Loss: 0.37540242075920105
# Iteration: 170, Loss: 0.3442390561103821
# Iteration: 175, Loss: 0.33594679832458496
# Iteration: 180, Loss: 0.3327239751815796
# Iteration: 185, Loss: 0.31762930750846863
# Iteration: 190, Loss: 0.37422996759414673
# Iteration: 195, Loss: 0.35868746042251587
# Time elasped:  4988.457643985748
# Training Loss

# %%
save_pth = 'mc_cnn_trained_w17.pth' #The filename to save your model, feel free to change the name
load_pth = 'mc_cnn_pretrain_w17.pth' #The filename to load previously trained model

net_tr = MCNET(ws=17, batch_size = 512, load_path = load_pth) 

max_epoch = 200
learning_rate = 0.01

optimizer = torch.optim.SGD(net_tr.net.parameters(), lr=learning_rate, momentum=0.9)
############################################

batch_size = net_tr.batch_size
ws = net_tr.ws

loss_history = run_net(model=net_tr,
                       nnz=nnz, 
                       batch_size=batch_size, 
                       ws=ws, 
                       max_epoch=max_epoch, 
                       split='train', 
                       optimizer=optimizer,
                       viz_frequency=viz_frequency, 
                       save_frequency=save_frequency,
                       fname = save_pth
                      )

print('Time elasped: ', time.time() - st) 

print('Training Loss')
plt.plot(loss_history)
plt.show()
# Out:
# Iteration: 0, Loss: 0.4073600172996521
# Iteration: 5, Loss: 0.4303045868873596
# Iteration: 10, Loss: 0.4210606813430786
# Iteration: 15, Loss: 0.41688454151153564
# Iteration: 20, Loss: 0.4533747732639313
# Iteration: 25, Loss: 0.3550509810447693
# Iteration: 30, Loss: 0.4305434226989746
# Iteration: 35, Loss: 0.36547818779945374
# Iteration: 40, Loss: 0.41690927743911743
# Iteration: 45, Loss: 0.4175550043582916
# Iteration: 50, Loss: 0.40761637687683105
# Iteration: 55, Loss: 0.4173523783683777
# Iteration: 60, Loss: 0.3600689470767975
# Iteration: 65, Loss: 0.34365931153297424
# Iteration: 70, Loss: 0.42822152376174927
# Iteration: 75, Loss: 0.39998626708984375
# Iteration: 80, Loss: 0.3794177174568176
# Iteration: 85, Loss: 0.3893268406391144
# Iteration: 90, Loss: 0.38668131828308105
# Iteration: 95, Loss: 0.41777992248535156
# Iteration: 100, Loss: 0.365532785654068
# Iteration: 105, Loss: 0.4096940755844116
# Iteration: 110, Loss: 0.38259851932525635
# Iteration: 115, Loss: 0.42988961935043335
# Iteration: 120, Loss: 0.34170001745224
# Iteration: 125, Loss: 0.3882918655872345
# Iteration: 130, Loss: 0.297461599111557
# Iteration: 135, Loss: 0.36446309089660645
# Iteration: 140, Loss: 0.3519518971443176
# Iteration: 145, Loss: 0.33270981907844543
# Iteration: 150, Loss: 0.3903849124908447
# Iteration: 155, Loss: 0.34546685218811035
# Iteration: 160, Loss: 0.3993823528289795
# Iteration: 165, Loss: 0.3491435647010803
# Iteration: 170, Loss: 0.35007941722869873
# Iteration: 175, Loss: 0.38433483242988586
# Iteration: 180, Loss: 0.35359132289886475
# Iteration: 185, Loss: 0.37478363513946533
# Iteration: 190, Loss: 0.33358705043792725
# Iteration: 195, Loss: 0.3425993323326111
# Time elasped:  5893.011997461319
# Training Loss

# %% [markdown]
# **Deliverables:** Training loss curves and validation loss for window sizes of 5, 9, 15 added to the report.
#
#
# **Questions**:
# 1.   What's the effect of varying the window size on performance? Do you suppose there is an optimal window size for all images? Explain why or why not.

# %% [markdown]
# **Answers:**
#
# 1. As we vary window size from 11 to 5, 9 & 17 the perfoemance of the model decreases and it is not able to reduce the loss as consistently as window size 11. Hence the optimal window size for all images in 11.

# %% [markdown]
# # Evaluate stereo matching

# %% [markdown]
# For this part we will again generate the disparity map but this time from our newly trained matching cost network instead of SAD/SSD. You should first **upload 2 files from part 1 (similarity_measures.py, disparity_map.py)** into colab environment. Click at the `>` sign on the top left, choose `Files` tab, then upload the 2 files into the current directory.
#
# Note that all the required functions in part 1 need to be implemented correctly before starting this part. Use this part to evaluate your trained network as a stereo matching cost.
#
# Hint: You don't have to re-train the network every time you want to evaluate, as long as your saved model is in Colab file system. Don't forget to change `load_path` to your best model,

# %%
###########Change to your best model here################

best_model = 'mc_cnn_trained_w11_1.pth' #Change this to your best model file
net_te = MCNET(batch_size = 30, load_path = best_model) 

############################################

# %%
try:
  from similarity_measures import sad_similarity_measure,ssd_similarity_measure
  from disparity_map import calculate_disparity_map
except ModuleNotFoundError:
  print('\033[91m Error: please upload disparity_map.py and similarity_measures.py from part 1\033[0m ')
from custom_utils import DataLoader
import numpy as np
import os
import time

ind_img = 162
scale = 1
im_left = X[ind_img][0][0][0][0][::scale,::scale]
im_right = X[ind_img][0][0][1][0][::scale,::scale]
im_dispnoc = dispnoc[ind_img][::scale,::scale]
im_dispnoc_full = dispnoc[ind_img]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1)
fig.set_figheight(5)
fig.set_figwidth(5*3)

ax1.imshow(im_left.cpu().numpy(), cmap="gray")
ax1.title.set_text('Left image')

ax2.imshow(im_right.cpu().numpy(), cmap="gray")
ax2.title.set_text('Right image')

ax3.imshow(im_dispnoc.cpu().numpy(), cmap="jet")
ax3.title.set_text('Ground Truth disparity')

# %%
# extract a patch of interest from the left image
patch_left_img = im_left[95:106, 265:276]

# get the search area in the right image
search_area_right_img = (im_right[95:106, 240:281])

plt.imshow(patch_left_img.cpu().numpy(), cmap='gray')
plt.show()
plt.imshow(search_area_right_img.cpu().numpy(),cmap='gray')
plt.show()

# %%
def cnn_batch_similarity_measure(patch1, strip, ws=11, max_search_bound=30):
    """

    """
    assert patch1.shape[0]==strip.shape[0]
    assert patch1.shape[1]==ws
    assert strip.shape[1]>=ws

    x = torch.zeros([max_search_bound*2, 1, ws, ws])
    max_range = min(max_search_bound, strip.shape[1]-ws+1)
    if isinstance(patch1,np.ndarray):
      patch1 = torch.tensor(patch1)
      patch1 = patch1.add(-patch1.mean()).div(patch1.std()).reshape(1,ws,ws)
    for i in range(max_range):
      x[i*2] = patch1
      patch2 = torch.tensor(strip[:,strip.shape[1]-ws-i:strip.shape[1]-i])
      patch2 = patch2.add(-patch2.mean()).div(patch2.std()).reshape(1,1,ws,ws)
      x[i*2 + 1] = patch2

    output = net_te(x.to(device))
    return output[:max_range].detach().cpu().numpy()

# %%
import time

fig = plt.figure(figsize=(12,4))

st = time.time()
similarity_vals = np.array([sad_similarity_measure(patch_left_img.cpu(), search_area_right_img[:,h_idx:(h_idx+11)].cpu()) for h_idx in range(search_area_right_img.shape[1]-11)])
print('SSD Took: ', time.time()-st)
plt.subplot(1, 3, 1)
plt.plot(similarity_vals[::-1])
plt.title('SSD')

st = time.time()
similarity_vals = np.array([ssd_similarity_measure(patch_left_img.cpu(), search_area_right_img[:,h_idx:(h_idx+11)].cpu()) for h_idx in range(search_area_right_img.shape[1]-11)])
print('SAD Took: ', time.time()-st)
plt.subplot(1, 3, 2)
plt.plot(similarity_vals[::-1])
plt.title('SAD')

max_search_bound = 30
net_te = MCNET(batch_size = max_search_bound, load_path = 'mc_cnn_pretrain_w11.pth') 
st = time.time()
similarity_vals = cnn_batch_similarity_measure(patch_left_img, search_area_right_img)
print('CNN Took: ', time.time()-st)
plt.subplot(1, 3, 3)
plt.plot(similarity_vals)
plt.title('MC-CNN')
fig.suptitle('Matching cost comparison')
plt.show()
# Out:
# SSD Took:  0.022354841232299805
# SAD Took:  0.013439416885375977
# CNN Took:  0.0182034969329834
# <ipython-input-36-e8890b92943d>:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   patch2 = torch.tensor(strip[:,strip.shape[1]-ws-i:strip.shape[1]-i])

# %% [markdown]
# **Deliverables:** copy the matching cost comparison to the report
#
# **Questions:**
#
#
# 1.   Based on the matching cost comparison plot, how are SSD, SAD, and MC-CNN different? Can you think of a scenario where matching with MC-CNN would be prefered over SSD/SAD?

# %% [markdown]
# **Answers**
#
# 1. SSD gives higher similarity values than SAD but resembles the same curve, i.e. they both drop around 15 and gives peak value at around 19. On the other hand MC-CNN gives close similarity value and then it gives peak similarity value at 19 after which the similarity value drops sharply.

# %%
def cnn_calculate_cost_volume(left_img: torch.Tensor,
                          right_img: torch.Tensor,
                          max_disparity: int,
                          cnn_batch_sim_function,
                          block_size: int = 9):
	#placeholder
	H = left_img.shape[0]
	W = right_img.shape[1]
	block_r = block_size//2
	cost_volume = torch.zeros(H, W, max_disparity) + 255

	for y in range(H):
		print("Done row: ",y)
		for x in range(W):

			y_l = y-block_r
			x_l = x-block_r

			# Ensure we can extract a full patch
			if (x_l < 0 or y_l < 0 or x_l > W-block_size or y_l > H-block_size):
				cost_volume[y,x,:] = 255
				continue
      
			# Extract patch starting at point (y,x) in left image
			left_patch = left_img[y_l:y_l+block_size, x_l:x_l+block_size,0]
			right_strip = right_img[y_l:y_l+block_size, 0:x_l+block_size,0]
			max_range = min(max_disparity,x_l)
			res = torch.tensor(cnn_batch_sim_function(left_patch, right_strip)[:])
			#print(res[:])
			cost_volume[y,x,:res.shape[0]] = res.T
	return cost_volume

def cnn_calculate_disparity_map(left_img: torch.Tensor,
                            right_img: torch.Tensor,
                            block_size: int,
                            cost_volume: torch.Tensor,
                            max_search_bound: int = 50) -> torch.Tensor:
	assert left_img.shape == right_img.shape
	disparity_map = torch.zeros(1) #placeholder, this is not the actual size
	H = left_img.shape[0]
	W = left_img.shape[1]
	block_r = block_size//2  # Block (Window) radius
	H_d = H-2*(block_r)
	W_d = W-2*(block_r)

	disparity_map = torch.zeros(H_d, W_d)
	for y in range(H_d):
		for x in range(W_d):
			min_err = 500
			min_d = torch.argmin(cost_volume[y,x])
			disparity_map[y,x] = min_d
	return disparity_map

# %% [markdown]
# The following cell can take around **an hour** to run, we suggest you only run this at the end when you are confident in the network you trained and want to evaluate the results. (HINT: your validation loss should be lower than 0.3 before you proceed.)

# %%
# calculate the disparity map with block size of 11 this will take awhile
import importlib
from cnn_disparity_map import cnn_calculate_disparity_map, cnn_calculate_cost_volume
st = time.time()
disp_map = calculate_disparity_map((im_left.cpu().unsqueeze(0).transpose(2,0).transpose(0,1)), #swap the channel
                                   (im_right.cpu().unsqueeze(0).transpose(2,0).transpose(0,1)), 
                                   block_size=11, 
                                   sim_measure_function = sad_similarity_measure,
                                   max_search_bound = 30)
t1 = time.time()
print('Time Elasped for SSD/SAD:', t1 - st)

cost_vol = cnn_calculate_cost_volume(im_left.unsqueeze(0).transpose(2,0).transpose(0,1), 
                                   im_right.unsqueeze(0).transpose(2,0).transpose(0,1), 
                                   30,
                                   cnn_batch_similarity_measure,
                                   11)

disp_map_cnn = cnn_calculate_disparity_map(im_left.unsqueeze(0).transpose(2,0).transpose(0,1), 
                                   im_right.unsqueeze(0).transpose(2,0).transpose(0,1), 
                                   block_size=11, 
                                   cost_volume=cost_vol,
                                   max_search_bound = 30)
print('Time Elasped for MC_CNN:', time.time() - t1)
# Out:
# Time Elasped for SSD/SAD: 188.62812113761902
# Done row:  0
# Done row:  1
# Done row:  2
# Done row:  3
# Done row:  4
# Done row:  5
# <ipython-input-36-e8890b92943d>:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   patch2 = torch.tensor(strip[:,strip.shape[1]-ws-i:strip.shape[1]-i])
# Done row:  6
# Done row:  7
# Done row:  8
# Done row:  9
# Done row:  10
# Done row:  11
# Done row:  12
# Done row:  13
# Done row:  14
# Done row:  15
# Done row:  16
# Done row:  17
# Done row:  18
# Done row:  19
# Done row:  20
# Done row:  21
# Done row:  22
# Done row:  23
# Done row:  24
# Done row:  25
# Done row:  26
# Done row:  27
# Done row:  28
# Done row:  29
# Done row:  30
# Done row:  31
# Done row:  32
# Done row:  33
# Done row:  34
# Done row:  35
# Done row:  36
# Done row:  37
# Done row:  38
# Done row:  39
# Done row:  40
# Done row:  41
# Done row:  42
# Done row:  43
# Done row:  44
# Done row:  45
# Done row:  46
# Done row:  47
# Done row:  48
# Done row:  49
# Done row:  50
# Done row:  51
# Done row:  52
# Done row:  53
# Done row:  54
# Done row:  55
# Done row:  56
# Done row:  57
# Done row:  58
# Done row:  59
# Done row:  60
# Done row:  61
# Done row:  62
# Done row:  63
# Done row:  64
# Done row:  65
# Done row:  66
# Done row:  67
# Done row:  68
# Done row:  69
# Done row:  70
# Done row:  71
# Done row:  72
# Done row:  73
# Done row:  74
# Done row:  75
# Done row:  76
# Done row:  77
# Done row:  78
# Done row:  79
# Done row:  80
# Done row:  81
# Done row:  82
# Done row:  83
# Done row:  84
# Done row:  85
# Done row:  86
# Done row:  87
# Done row:  88
# Done row:  89
# Done row:  90
# Done row:  91
# Done row:  92
# Done row:  93
# Done row:  94
# Done row:  95
# Done row:  96
# Done row:  97
# Done row:  98
# Done row:  99
# Done row:  100
# Done row:  101
# Done row:  102
# Done row:  103
# Done row:  104
# Done row:  105
# Done row:  106
# Done row:  107
# Done row:  108
# Done row:  109
# Done row:  110
# Done row:  111
# Done row:  112
# Done row:  113
# Done row:  114
# Done row:  115
# Done row:  116
# Done row:  117
# Done row:  118
# Done row:  119
# Done row:  120
# Done row:  121
# Done row:  122
# Done row:  123
# Done row:  124
# Done row:  125
# Done row:  126
# Done row:  127
# Done row:  128
# Done row:  129
# Done row:  130
# Done row:  131
# Done row:  132
# Done row:  133
# Done row:  134
# Done row:  135
# Done row:  136
# Done row:  137
# Done row:  138
# Done row:  139
# Done row:  140
# Done row:  141
# Done row:  142
# Done row:  143
# Done row:  144
# Done row:  145
# Done row:  146
# Done row:  147
# Done row:  148
# Done row:  149
# Time Elasped for MC_CNN: 814.2925262451172

# %%
from cv2 import resize
def evaluate_stereo(gt, disp):
  
  max_disp = 280
  mask = gt!=np.inf

  if disp.shape != gt.shape:
    ratio = float(gt.shape[1])/disp.shape[1]
    disp=resize(disp,(gt.shape[0],gt.shape[1])).transpose()*ratio
  disp[disp>max_disp]=max_disp
  
  errmap = np.abs(gt-disp)*mask
  avgerr = errmap[mask].mean()
  bad1map = (errmap>1) * mask
  bad1 = bad1map[mask].sum()/float(mask.sum())*100 #percentage of bad pixels whose error is greater than 1

  bad2map = (errmap>2) * mask
  bad2 = bad2map[mask].sum()/float(mask.sum())*100

  bad4map = (errmap>4) * mask
  bad4 = bad4map[mask].sum()/float(mask.sum())*100
  
  return avgerr, bad1, bad2, bad4

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3,1)
fig.set_figheight(9)
fig.set_figwidth(15)

ax1.imshow(im_left.cpu().numpy(), cmap="gray")
ax1.title.set_text('Left image')

ax2.imshow(im_right.cpu().numpy(), cmap="gray")
ax2.title.set_text('Right image')

ratio = float(im_dispnoc_full.shape[1])/disp_map.shape[1] #ratio for the actual disparity in pixel

ax3.imshow(im_dispnoc.cpu().numpy()/ratio, cmap="jet", interpolation='nearest')
ax3.title.set_text('Ground Truth disparity')
fig, (ax4, ax5) = plt.subplots(2,1)
fig.set_figheight(6)
fig.set_figwidth(15)

ax4.imshow((disp_map.cpu().numpy()), cmap='jet', interpolation='nearest')
ax4.title.set_text('SAD Disparity map')

ax5.imshow((disp_map_cnn.cpu().numpy().astype(np.float32))*50, cmap='jet')
ax5.title.set_text('MCCNN Disparity map')

plt.show()

cnn_avgerr, cnn_bad1, cnn_bad2, cnn_bad4 = evaluate_stereo(im_dispnoc_full.cpu().numpy(),disp_map_cnn.cpu().numpy().astype(np.float32))
sad_avgerr,  sad_bad1, sad_bad2, sad_bad4 = evaluate_stereo(im_dispnoc_full.cpu().numpy(),disp_map.cpu().numpy().astype(np.float32))


print('--------------------------------------------------------------------------')
print('Metrics: \t\t', 'SAD','\t\t\t','MCCNN')
print('--------------------------------------------------------------------------')
print('Average Error \t\t',sad_avgerr,'\t\t', cnn_avgerr)
print('%error > 1 pixel\t', sad_bad1,'\t',cnn_bad1)
print('%error > 2 pixels\t',sad_bad2, '\t',cnn_bad2)
print('%error > 4 pixels\t',sad_bad4, '\t', cnn_bad4)
# Out:
# --------------------------------------------------------------------------
# Metrics: 		 SAD 			 MCCNN
# --------------------------------------------------------------------------
# Average Error 		 14.942535 		 13.463752
# %error > 1 pixel	 96.65599999999999 	 93.53533333333334
# %error > 2 pixels	 94.14 	 90.42933333333333
# %error > 4 pixels	 84.73733333333332 	 81.382

# %% [markdown]
# **Deliverables:** Make a screen shot of the disparity map and the evaluation results above and copy them to the report.
#
# **Questions:**
#
#
# 1.   Qualitatively, between SAD and MCCNN, which disparity map do you think looks better? Explain your reasoning.
# 2.   Quantitatively, between SAD and MCCNN, which one acieve better score on the metrics? Why do you think that's the case?

# %% [markdown]
# **Answers**
#
# 1. Qualitatively SAD disparity map looks better as the map is smooth in values and the structure of the objects closer can be seen more clearer than compared to MCCNN
#
# 2. Quantitatively MCCNN achieves better score. This is the case because MCCNN is capable of finding peaks at high disparity values as compared SAD due to the way the MCCNN is trained. Hence the MCCNN achieves a better quantitative score.
